# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import imageio.v3 as iio
import numpy as np
import matplotlib.pyplot as plt
import copy

# !pip install torchmetrics
import torchmetrics

# !pip install einops
import einops
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.10/dist-packages (0.11.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (23.1)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (2.0.0+cu118)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (1.22.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (1.11.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (2.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (3.12.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (3.1.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (3.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.1->torchmetrics) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.1->torchmetrics) (16.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.1->torchmetrics) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.1->torchmetrics) (1.3.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (0.6.1)

# %%
# !pip install -U segmentation-models-pytorch
import segmentation_models_pytorch as smp
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: segmentation-models-pytorch in /usr/local/lib/python3.10/dist-packages (0.3.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (4.65.0)
# Requirement already satisfied: torchvision>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (0.15.1+cu118)
# Requirement already satisfied: pretrainedmodels==0.7.4 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (0.7.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (8.4.0)
# Requirement already satisfied: timm==0.6.12 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (0.6.12)
# Requirement already satisfied: efficientnet-pytorch==0.7.1 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-pytorch) (0.7.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (2.0.0+cu118)
# Requirement already satisfied: munch in /usr/local/lib/python3.10/dist-packages (from pretrainedmodels==0.7.4->segmentation-models-pytorch) (2.5.0)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from timm==0.6.12->segmentation-models-pytorch) (0.14.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm==0.6.12->segmentation-models-pytorch) (6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.5.0->segmentation-models-pytorch) (2.27.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.5.0->segmentation-models-pytorch) (1.22.4)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (2.0.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (1.11.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (3.1.2)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (16.0.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm==0.6.12->segmentation-models-pytorch) (2023.4.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm==0.6.12->segmentation-models-pytorch) (23.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from munch->pretrainedmodels==0.7.4->segmentation-models-pytorch) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (1.3.0)

# %%
# !gdown https://drive.google.com/uc?id=1lWTIkjK53YfXHy8HoOH4spNyvAEiDxI2
# !mv Dataset_Student_annot_copy.zip Dataset_Student_annot.zip
#https://drive.google.com/file/d/1lWTIkjK53YfXHy8HoOH4spNyvAEiDxI2/view?usp=share_link
# !unzip Dataset_Student_annot.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Dataset_Student/val/data/video_1941/image_11.png
#   inflating: __MACOSX/Dataset_Student/val/data/video_1941/._image_11.png
#   inflating: Dataset_Student/val/data/video_1941/image_8.png
#   inflating: __MACOSX/Dataset_Student/val/data/video_1941/._image_8.png
#   inflating: Dataset_Student/val/data/video_1941/image_9.png
#   inflating: __MACOSX/Dataset_Student/val/data/video_1941/._image_9.png
#   inflating: Dataset_Student/val/data/video_1941/mask.npy
#   inflating: __MACOSX/Dataset_Student/val/data/video_1941/._mask.npy
#   inflating: Dataset_Student/val/data/video_1941/image_2.png
#   inflating: __MACOSX/Dataset_Student/val/data/video_1941/._image_2.png
#   inflating: Dataset_Student/val/data/video_1941/image_3.png
#   inflating: __MACOSX/Dataset_Student/val/data/video_1941/._image_3.png
#   inflating: Dataset_Student/val/data/video_1941/image_1.png
#   inflating: __MACOSX/Dataset_Student/val/data/video_1941/._image_1.png
#   inflating: Dataset_Student/val/data/video_1941/image_0.png
#   inflating: __MACOSX/Dataset_Student/val/data/video_1941/._image_0.png
#   inflating: Dataset_Student/val/data/video_1941/image_4.png
#   inflating: __MACOSX/Dataset_Student/val/data/video_1941/._image_4.png
#   inflating: Dataset_Student/val/data/video_1941/image_5.png
#   inflating: __MACOSX/Dataset_Student/val/data/video_1941/._image_5.png
#   inflating: Dataset_Student/val/data/video_1941/image_7.png
#   inflating: __MACOSX/Dataset_Student/val/data/video_1941/._image_7.png
#   inflating: Dataset_Student/val/data/video_1941/image_6.png
#   inflating: __MACOSX/Dataset_Student/val/data/video_1941/._image_6.png
#   inflating: Dataset_Student/val/data/video_1941/image_20.png
#   inflating: __MACOSX/Dataset_Student/val/data/video_1941/._image_20.png
#   inflating: Dataset_Student/val/data/video_1941/image_21.png
#   inflating: __MACOSX/Dataset_Student/val/data/video_1941/._image_21.png
#   inflating: Dataset_Student/val/data/video_1941/image_19.png
#   inflating: __MACOSX/Dataset_Student/val/data/video_
png
#   inflating: __MACOSX/Dataset_Student/val/data/video_1542/._image_12.png
#   inflating: Dataset_Student/val/data/video_1542/image_10.png
#   inflating: __MACOSX/Dataset_Student/val/data/video_1542/._image_10.png
#   inflating: Dataset_Student/val/data/video_1542/image_11.png
#   inflating: __MACOSX/Dataset_Student/val/data/video_1542/._image_11.png
#   inflating: Dataset_Student/val/data/video_1542/image_8.png
#   inflating: __MACOSX/Dataset_Student/val/data/video_1542/._image_8.png
#   inflating: Dataset_Student/val/data/video_1542/image_9.png
#   inflating: __MACOSX/Dataset_Student/val/data/video_1542/._image_9.png
#   inflating: Dataset_Student/val/data/video_1542/mask.npy
#   inflating: __MACOSX/Dataset_Student/val/data/video_1542/._mask.npy
#   inflating: Dataset_Student/val/data/video_1542/image_2.png
#   inflating: __MACOSX/Dataset_Student/val/data/video_1542/._image_2.png
#   inflating: Dataset_Student/val/data/video_1542/image_3.png
#   inflating: __MACOSX/Dataset_Student/val/data/video_1542/._image_3.png
#   inflating: Dataset_Student/val/data/video_1542/image_1.png
#   inflating: __MACOSX/Dataset_Student/val/data/video_1542/._image_1.png
#   inflating: Dataset_Student/val/data/video_1542/image_0.png
#   inflating: __MACOSX/Dataset_Student/val/data/video_1542/._image_0.png
#   inflating: Dataset_Student/val/data/video_1542/image_4.png
#   inflating: __MACOSX/Dataset_Student/val/data/video_1542/._image_4.png
#   inflating: Dataset_Student/val/data/video_1542/image_5.png
#   inflating: __MACOSX/Dataset_Student/val/data/video_1542/._image_5.png
#   inflating: Dataset_Student/val/data/video_1542/image_7.png
#   inflating: __MACOSX/Dataset_Student/val/data/video_1542/._image_7.png
#   inflating: Dataset_Student/val/data/video_1542/image_6.png
#   inflating: __MACOSX/Dataset_Student/val/data/video_1542/._image_6.png
#   inflating: Dataset_Student/val/data/video_1542/image_20.png
#   inflating: __MACOSX/Dataset_Student/val/data/video_1542/._image_20.png
#   inflating: Dataset_Student/val/data/video_1542/image_21.png
#   inflating: __MACOSX/Dataset_Student/val/data/video_1542/._image_21.png
#   inflating: Dataset_Student/val/data/video_1542/image_19.png
#   inflating: __MACOSX/Dataset_Student/val/data/video_1542/._image_19.png
#   inflating: Dataset_Student/val/data/video_1542/image_18.png
#   inflating: __MACOSX/Dataset_Student/val/data/video_1542/._image_18.png

# %%
import os
import os.path
import numpy as np
from PIL import Image
from torchvision import transforms
import torch
from typing import List, Union, Tuple, Any


class VideoRecord(object):
    """
    Helper class for class VideoFrameDataset. This class
    represents a video sample's metadata.

    Args:
        root_datapath: the system path to the root folder
                       of the videos.
        row: A list with four or more elements where 1) The first
             element is the path to the video sample's frames excluding
             the root_datapath prefix 2) The  second element is the starting frame id of the video
             3) The third element is the inclusive ending frame id of the video
             4) The fourth element is the label index.
             5) any following elements are labels in the case of multi-label classification
    """
    def __init__(self, row, root_datapath):
        self._data = row
        self._path = os.path.join(root_datapath, row[0])


    @property
    def path(self) -> str:
        return self._path

    @property
    def num_frames(self) -> int:
        return self.end_frame - self.start_frame + 1  # +1 because end frame is inclusive
    @property
    def start_frame(self) -> int:
        return int(self._data[1])

    @property
    def end_frame(self) -> int:
        return int(self._data[2])

    @property
    def label(self) -> Union[int, List[int]]:
        # just one label_id
        if len(self._data) == 4:
            return int(self._data[3])
        # sample associated with multiple labels
        else:
            return [int(label_id) for label_id in self._data[3:]]

class VideoFrameDataset(torch.utils.data.Dataset):
    r"""
    A highly efficient and adaptable dataset class for videos.
    Instead of loading every frame of a video,
    loads x RGB frames of a video (sparse temporal sampling) and evenly
    chooses those frames from start to end of the video, returning
    a list of x PIL images or ``FRAMES x CHANNELS x HEIGHT x WIDTH``
    tensors where FRAMES=x if the ``ImglistToTensor()``
    transform is used.

    More specifically, the frame range [START_FRAME, END_FRAME] is divided into NUM_SEGMENTS
    segments and FRAMES_PER_SEGMENT consecutive frames are taken from each segment.

    Note:
        A demonstration of using this class can be seen
        in ``demo.py``
        https://github.com/RaivoKoot/Video-Dataset-Loading-Pytorch

    Note:
        This dataset broadly corresponds to the frame sampling technique
        introduced in ``Temporal Segment Networks`` at ECCV2016
        https://arxiv.org/abs/1608.00859.


    Note:
        This class relies on receiving video data in a structure where
        inside a ``ROOT_DATA`` folder, each video lies in its own folder,
        where each video folder contains the frames of the video as
        individual files with a naming convention such as
        img_001.jpg ... img_059.jpg.
        For enumeration and annotations, this class expects to receive
        the path to a .txt file where each video sample has a row with four
        (or more in the case of multi-label, see README on Github)
        space separated values:
        ``VIDEO_FOLDER_PATH     START_FRAME      END_FRAME      LABEL_INDEX``.
        ``VIDEO_FOLDER_PATH`` is expected to be the path of a video folder
        excluding the ``ROOT_DATA`` prefix. For example, ``ROOT_DATA`` might
        be ``home\data\datasetxyz\videos\``, inside of which a ``VIDEO_FOLDER_PATH``
        might be ``jumping\0052\`` or ``sample1\`` or ``00053\``.

    Args:
        root_path: The root path in which video folders lie.
                   this is ROOT_DATA from the description above.
        annotationfile_path: The .txt annotation file containing
                             one row per video sample as described above.
        num_segments: The number of segments the video should
                      be divided into to sample frames from.
        frames_per_segment: The number of frames that should
                            be loaded per segment. For each segment's
                            frame-range, a random start index or the
                            center is chosen, from which frames_per_segment
                            consecutive frames are loaded.
        imagefile_template: The image filename template that video frame files
                            have inside of their video folders as described above.
        transform: Transform pipeline that receives a list of PIL images/frames.
        test_mode: If True, frames are taken from the center of each
                   segment, instead of a random location in each segment.

    """
    def __init__(self,
                 root_path: str,
                 annotationfile_path: str,
                 num_segments: int = 3,
                 frames_per_segment: int = 1,
                 imagefile_template: str='image_{:d}.png',
                 transform = None,
                 mask: bool =False,
                 mask_template: str='mask.npy',
                 test_mode: bool = False):
        super(VideoFrameDataset, self).__init__()

        self.root_path = root_path
        self.annotationfile_path = annotationfile_path
        self.num_segments = num_segments
        self.frames_per_segment = frames_per_segment
        self.imagefile_template = imagefile_template
        self.transform = transform
        self.mask = mask
        self.mask_template = mask_template
        self.test_mode = test_mode

        self._parse_annotationfile()
        self._sanity_check_samples()

    def _load_image(self, directory: str, idx: int) -> Image.Image:
        return Image.open(os.path.join(directory, self.imagefile_template.format(idx))).convert('RGB')
    
    def _load_mask(self, directory: str) -> torch.Tensor:
        return torch.Tensor(np.load(os.path.join(directory, self.mask_template)))

    def _parse_annotationfile(self):
        self.video_list = [VideoRecord(x.strip().split(), self.root_path) for x in open(self.annotationfile_path)]

    def _sanity_check_samples(self):
        for record in self.video_list:
            if record.num_frames <= 0 or record.start_frame == record.end_frame:
                print(f"\nDataset Warning: video {record.path} seems to have zero RGB frames on disk!\n")

            elif record.num_frames < (self.num_segments * self.frames_per_segment):
                print(f"\nDataset Warning: video {record.path} has {record.num_frames} frames "
                      f"but the dataloader is set up to load "
                      f"(num_segments={self.num_segments})*(frames_per_segment={self.frames_per_segment})"
                      f"={self.num_segments * self.frames_per_segment} frames. Dataloader will throw an "
                      f"error when trying to load this video.\n")

    def _get_start_indices(self, record: VideoRecord) -> 'np.ndarray[int]':
        """
        For each segment, choose a start index from where frames
        are to be loaded from.

        Args:
            record: VideoRecord denoting a video sample.
        Returns:
            List of indices of where the frames of each
            segment are to be loaded from.
        """
        # choose start indices that are perfectly evenly spread across the video frames.
        if self.test_mode:
            distance_between_indices = (record.num_frames - self.frames_per_segment + 1) / float(self.num_segments)

            start_indices = np.array([int(distance_between_indices / 2.0 + distance_between_indices * x)
                                      for x in range(self.num_segments)])
        # randomly sample start indices that are approximately evenly spread across the video frames.
        else:
            max_valid_start_index = (record.num_frames - self.frames_per_segment + 1) // self.num_segments

            start_indices = np.multiply(list(range(self.num_segments)), max_valid_start_index) + \
                      np.random.randint(max_valid_start_index, size=self.num_segments)

        return start_indices

    def __getitem__(self, idx: int) -> Union[
        Tuple[List[Image.Image], Union[int, List[int]]],
        Tuple['torch.Tensor[num_frames, channels, height, width]', Union[int, List[int]]],
        Tuple[Any, Union[int, List[int]]],
        ]:
        """
        For video with id idx, loads self.NUM_SEGMENTS * self.FRAMES_PER_SEGMENT
        frames from evenly chosen locations across the video.

        Args:
            idx: Video sample index.
        Returns:
            A tuple of (video, label). Label is either a single
            integer or a list of integers in the case of multiple labels.
            Video is either 1) a list of PIL images if no transform is used
            2) a batch of shape (NUM_IMAGES x CHANNELS x HEIGHT x WIDTH) in the range [0,1]
            if the transform "ImglistToTensor" is used
            3) or anything else if a custom transform is used.
        """
        record: VideoRecord = self.video_list[idx]

        frame_start_indices: 'np.ndarray[int]' = self._get_start_indices(record)

        return self._get(record, frame_start_indices)

    def _get(self, record: VideoRecord, frame_start_indices: 'np.ndarray[int]') -> Union[
        Tuple[List[Image.Image], Union[int, List[int]]],
        Tuple['torch.Tensor[num_frames, channels, height, width]', Union[int, List[int]]],
        Tuple[Any, Union[int, List[int]]],
        ]:
        """
        Loads the frames of a video at the corresponding
        indices.

        Args:
            record: VideoRecord denoting a video sample.
            frame_start_indices: Indices from which to load consecutive frames from.
        Returns:
            A tuple of (video, label). Label is either a single
            integer or a list of integers in the case of multiple labels.
            Video is either 1) a list of PIL images if no transform is used
            2) a batch of shape (NUM_IMAGES x CHANNELS x HEIGHT x WIDTH) in the range [0,1]
            if the transform "ImglistToTensor" is used
            3) or anything else if a custom transform is used.
        """

        frame_start_indices = frame_start_indices + record.start_frame
        images = list()

        # from each start_index, load self.frames_per_segment
        # consecutive frames
        for start_index in frame_start_indices:
            frame_index = int(start_index)

            # load self.frames_per_segment consecutive frames
            for _ in range(self.frames_per_segment):
                image = self._load_image(record.path, frame_index)
                images.append(image)

                if frame_index < record.end_frame:
                    frame_index += 1

        if self.transform is not None:
            images = self.transform(images)

        if self.mask:
            mask = self._load_mask(record.path)
            return images, record.label, mask

        return images, record.label

    def __len__(self):
        return len(self.video_list)

class ImglistToTensor(torch.nn.Module):
    """
    Converts a list of PIL images in the range [0,255] to a torch.FloatTensor
    of shape (NUM_IMAGES x CHANNELS x HEIGHT x WIDTH) in the range [0,1].
    Can be used as first transform for ``VideoFrameDataset``.
    """
    @staticmethod
    def forward(img_list: List[Image.Image]) -> 'torch.Tensor[NUM_IMAGES, CHANNELS, HEIGHT, WIDTH]':
        """
        Converts each PIL image in a list to
        a torch Tensor and stacks them into
        a single tensor.

        Args:
            img_list: list of PIL images.
        Returns:
            tensor of size ``NUM_IMAGES x CHANNELS x HEIGHT x WIDTH``
        """
        return torch.stack([transforms.functional.to_tensor(pic) for pic in img_list])

# %%
### Dataloader method
def load_data(root, annotation_file, batch_size=2):
    preprocess = transforms.Compose([
            ImglistToTensor(),  # list of PIL images to (FRAMES x CHANNELS x HEIGHT x WIDTH) tensor
            # transforms.Resize(299),  # image batch, resize smaller edge to 299
            # transforms.Resize((160,240)),
            # transforms.CenterCrop(299),  # image batch, center crop to square 299x299
            transforms.Normalize((0.61749697, 0.6050092, 0.52180636), (2.1824553, 2.1553133, 1.9115673)),
        ])

    dataset = VideoFrameDataset(
        root_path=root,
        annotationfile_path=annotation_file,
        num_segments=1,
        frames_per_segment=22,
        imagefile_template='image_{:d}.png',
        transform=preprocess,
        mask=True,
        test_mode=False
    )

    dataloader = torch.utils.data.DataLoader(
            dataset=dataset,
            batch_size=batch_size,
            shuffle=True,
            num_workers=2, # arbitrarily chosen
            pin_memory=True
        )
    return dataloader

### Load the train and validation datasets
batch_size = 2
trainloader = load_data('Dataset_Student/train/data/', 'Dataset_Student/train/annotations.txt', batch_size)
valloader = load_data('Dataset_Student/val/data/', 'Dataset_Student/val/annotations.txt', batch_size)

# %%
#Unet_masker = smp.Unet(
#    encoder_name="resnet34",        # choose encoder, e.g. mobilenet_v2 or efficientnet-b7
#    encoder_weights=None,           # use `imagenet` pre-trained weights for encoder initialization
#    in_channels=3,                  # model input channels (1 for gray-scale images, 3 for RGB, etc.)
#    classes=49,                      # model output channels (number of classes in your dataset)
#)

# %%
#import unet
#Unet_masker = unet.UNet2D(in_channels=3, out_classes=49)

# %%
### Code from: https://github.com/usuyama/pytorch-unet/blob/master/pytorch_unet.py

import torch
import torch.nn as nn

def double_conv(in_channels, out_channels):
    return nn.Sequential(
        nn.Conv2d(in_channels, out_channels, 3, padding=1),
        nn.BatchNorm2d(out_channels),
        nn.ReLU(inplace=True),
        nn.Conv2d(out_channels, out_channels, 3, padding=1),
        nn.BatchNorm2d(out_channels),
        nn.ReLU(inplace=True)
    )   


class UNet(nn.Module):

    def __init__(self, n_class):
        super().__init__()
                
        self.dconv_down1 = double_conv(3, 64)
        self.dconv_down2 = double_conv(64, 128)
        self.dconv_down3 = double_conv(128, 256)
        self.dconv_down4 = double_conv(256, 512)        

        self.maxpool = nn.MaxPool2d(2)
        self.upsample = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)        
        
        self.dconv_up3 = double_conv(256 + 512, 256)
        self.dconv_up2 = double_conv(128 + 256, 128)
        self.dconv_up1 = double_conv(128 + 64, 64)
        
        self.conv_last = nn.Conv2d(64, n_class, 1)
        
        
    def forward(self, x):
        conv1 = self.dconv_down1(x)
        x = self.maxpool(conv1)

        conv2 = self.dconv_down2(x)
        x = self.maxpool(conv2)
        
        conv3 = self.dconv_down3(x)
        x = self.maxpool(conv3)   
        
        x = self.dconv_down4(x)
        
        x = self.upsample(x)        
        x = torch.cat([x, conv3], dim=1)
        
        x = self.dconv_up3(x)
        x = self.upsample(x)        
        x = torch.cat([x, conv2], dim=1)       

        x = self.dconv_up2(x)
        x = self.upsample(x)        
        x = torch.cat([x, conv1], dim=1)   
        
        x = self.dconv_up1(x)
        
        out = self.conv_last(x)
        
        return out

# %%
Unet_masker = UNet(                 # model input channels (1 for gray-scale images, 3 for RGB, etc.)
    n_class=49,                      # model output channels (number of classes in your dataset)
)

# %%
# Set device to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
from torch.nn.modules.loss import CrossEntropyLoss

class CEandDiceLoss(nn.Module):
    def __init__(self, ce_class_weights, ce_weight=0.5, dice_weight=0.5):
        super(CEandDiceLoss, self).__init__()
        self.ce_weight = ce_weight
        self.dice_weight = dice_weight
        self.ce_loss = nn.CrossEntropyLoss()
        self.dice_loss = smp.losses.DiceLoss(mode="multiclass")
    
    def forward(self, pred, target):
        ce_loss = self.ce_loss(pred, target)
        dice_loss = self.dice_loss(pred, target)
        combined_loss = self.ce_weight * ce_loss + self.dice_weight * dice_loss

        return combined_loss

# %%
from torch.optim.lr_scheduler import CosineAnnealingLR
from torch import optim


num_epochs = 5
#criterion = smp.losses.JaccardLoss(mode="multiclass")
weight = torch.ones(49)
weight[0] = 0.3
weight = weight.to(device)
steps = num_epochs * len(trainloader)
criterion = CEandDiceLoss(weight, 0.3, 0.7) #smp.losses.DiceLoss(mode="multiclass")#CrossEntropyLoss(weight=weight)
optimizer = optim.Adam(Unet_masker.parameters(), lr=0.000001)
scheduler = CosineAnnealingLR(optimizer, T_max=steps, eta_min=0.00000001)

# %%
from tqdm import tqdm
from einops import rearrange



Unet_masker.to(device)

def train_model(model, trainloader, valloader, optimizer, criterion, device, epochs):
  # Training loop
  for epoch in range(epochs):
      # Training
      model.train()
      train_loss = 0
      train_tqdm = tqdm(trainloader, desc=f"Epoch {epoch+1}/{num_epochs} (Train)")
      for frames, labels, masks in train_tqdm:
          frames, labels, masks = frames.to(device), labels.to(device), masks.to(device)

          optimizer.zero_grad()
          frames = rearrange(frames, 'b t c h w -> (b t) c h w')
          masks = rearrange(masks, 'b t h w -> (b t) h w')
          #print(frames.shape)
          outputs = model(frames)
          #print(outputs.shape)
          #print(masks.shape)
          loss = criterion(outputs, masks.long())
          loss.backward()
          optimizer.step()
          scheduler.step()

          train_loss += loss.item()
          train_tqdm.set_postfix({'train_loss': train_loss / (train_tqdm.n + 1), 'learning_rate': optimizer.param_groups[0]['lr']})

      # Validation
      model.eval()
      val_loss = 0
      val_tqdm = tqdm(valloader, desc=f"Epoch {epoch+1}/{num_epochs} (Val)")
      with torch.no_grad():
          val_predicted = []
          val_truth = []
          for frames, labels, masks in val_tqdm:
              frames, labels, masks = frames.to(device), labels.to(device), masks.to(device)

              frames = rearrange(frames, 'b t c h w -> (b t) c h w')
              masks = rearrange(masks, 'b t h w -> (b t) h w')
              outputs = model(frames)
              loss = criterion(outputs, masks.long())

              outputs = torch.argmax(outputs, dim=1)
              val_predicted.append(outputs[[21,43]].cpu())
              val_truth.append(masks[[21,43]].cpu())

              val_loss += loss.item()
              val_tqdm.set_postfix({'val_loss': val_loss / (val_tqdm.n + 1)})

          # Convert the tensors to numpy arrays for visualization
          print(outputs.shape)
          print(masks.shape)
          outputs = outputs.cpu().numpy()
          masks = masks.cpu().numpy()
          # Choose the first sample in the batch to visualize
          sample_id = 0

          # Plot the predicted mask and real mask
          fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
          ax1.imshow(outputs[sample_id])
          ax1.set_title("Predicted Mask")
          ax2.imshow(masks[sample_id])
          ax2.set_title("Real Mask")
          plt.show()

          results_mask_tensor = torch.cat(val_predicted, dim=0)  # Concatenate tensors
          actual_mask_tensor = torch.cat(val_truth, dim=0)
          jaccard = compute_jaccard(results_mask_tensor, actual_mask_tensor)
          print(f"jaccard_score: {jaccard}")


train_model(Unet_masker, trainloader, valloader, optimizer, criterion, device, num_epochs)
# Out:
# Epoch 1/5 (Train): 100%|██████████| 500/500 [01:44<00:00,  4.80it/s, train_loss=0.0233, learning_rate=9.05e-7]
# Epoch 1/5 (Val): 100%|██████████| 500/500 [00:42<00:00, 11.65it/s, val_loss=0.0229]
# torch.Size([44, 160, 240])
# torch.Size([44, 160, 240])
# jaccard_score: 0.9343822002410889
# Epoch 2/5 (Train): 100%|██████████| 500/500 [01:44<00:00,  4.80it/s, train_loss=0.0229, learning_rate=6.58e-7]
# Epoch 2/5 (Val): 100%|██████████| 500/500 [00:42<00:00, 11.64it/s, val_loss=0.0227]
# torch.Size([44, 160, 240])
# torch.Size([44, 160, 240])
# jaccard_score: 0.9352805614471436
# Epoch 3/5 (Train): 100%|██████████| 500/500 [01:44<00:00,  4.80it/s, train_loss=0.0227, learning_rate=3.52e-7]
# Epoch 3/5 (Val): 100%|██████████| 500/500 [00:42<00:00, 11.63it/s, val_loss=0.0232]
# torch.Size([44, 160, 240])
# torch.Size([44, 160, 240])
# jaccard_score: 0.9355959892272949
# Epoch 4/5 (Train): 100%|██████████| 500/500 [01:44<00:00,  4.80it/s, train_loss=0.0226, learning_rate=1.05e-7]
# Epoch 4/5 (Val): 100%|██████████| 500/500 [00:42<00:00, 11.64it/s, val_loss=0.0226]
# torch.Size([44, 160, 240])
# torch.Size([44, 160, 240])
# jaccard_score: 0.935500979423523
# Epoch 5/5 (Train): 100%|██████████| 500/500 [01:44<00:00,  4.80it/s, train_loss=0.0226, learning_rate=1e-8]
# Epoch 5/5 (Val): 100%|██████████| 500/500 [00:42<00:00, 11.64it/s, val_loss=0.0226]
# torch.Size([44, 160, 240])
# torch.Size([44, 160, 240])
# jaccard_score: 0.9359220862388611

# %%
torch.save(Unet_masker.state_dict(), "best_model_15_epochs.pkl")

# %%
### Load model:
unet_saved_data = torch.load("best_model_15_epochs.pkl", map_location=device)
Unet_masker.load_state_dict(unet_saved_data)
Unet_masker.to(device)
# Out:
# UNet(
#   (dconv_down1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (dconv_down2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (dconv_down3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (dconv_down4): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (maxpool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (upsample): Upsample(scale_factor=2.0, mode='bilinear')
#   (dconv_up3): Sequential(
#     (0): Conv2d(768, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (dconv_up2): Sequential(
#     (0): Conv2d(384, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (dconv_up1): Sequential(
#     (0): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (conv_last): Conv2d(64, 49, kernel_size=(1, 1), stride=(1, 1))
# )

# %%
### Generate masks for unlabeled
from tqdm import tqdm
from einops import rearrange

### Unlabeled Dataloader method
def load_unlabeled_data(root, annotation_file, batch_size=1):
    preprocess = transforms.Compose([
            ImglistToTensor(),  # list of PIL images to (FRAMES x CHANNELS x HEIGHT x WIDTH) tensor
            # transforms.Resize(299),  # image batch, resize smaller edge to 299
            # transforms.Resize((160,240)),
            # transforms.CenterCrop(299),  # image batch, center crop to square 299x299
            transforms.Normalize((0.61749697, 0.6050092, 0.52180636), (2.1824553, 2.1553133, 1.9115673)),
        ])

    dataset = VideoFrameDataset(
        root_path=root,
        annotationfile_path=annotation_file,
        num_segments=1,
        frames_per_segment=22,
        imagefile_template='image_{:d}.png',
        transform=preprocess,
        mask=False,
        test_mode=False
    )

    dataloader = torch.utils.data.DataLoader(
            dataset=dataset,
            batch_size=batch_size,
            shuffle=False,
            num_workers=1, # arbitrarily chosen
            pin_memory=True
        )
    return dataloader

unlabeledloader = load_unlabeled_data('Dataset_Student/unlabeled/data/', 'Dataset_Student/unlabeled/annotations.txt', 1)

# this maybe only works with batch size 1 (?) so test if using with more
#def generate_unlabeled_masks(model, unlabeledloader):
#  model.eval()
#  unlabeled_tqdm = tqdm(unlabeledloader, desc=f"(Generating)")
#  output_masks = []
#  for frames, labels in unlabeled_tqdm:
#      frames, labels = frames.to(device), labels.to(device)
#
#      with torch.no_grad():
#        frames = rearrange(frames, 'b t c h w -> (b t) c h w')
#        outputs = model(frames)
#        outputs = torch.argmax(outputs, dim=1)
#        outputs = outputs.unsqueeze(0)
#        output_masks.append(outputs.cpu())
#  
#  results_mask_tensor = torch.cat(output_masks, dim=0)
#  print(results_mask_tensor.shape)
#
#  return results_mask_tensor

import os
import torch

def generate_unlabeled_masks(model, unlabeledloader, save_dir='output_masks'):
    model.eval()
    unlabeled_tqdm = tqdm(unlabeledloader, desc=f"(Generating)")

    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    for idx, (frames, labels) in enumerate(unlabeled_tqdm):
        frames, labels = frames.to(device), labels.to(device)

        with torch.no_grad():
            frames = rearrange(frames, 'b t c h w -> (b t) c h w')
            outputs = model(frames)
            outputs = torch.argmax(outputs, dim=1)
            output_file = os.path.join(save_dir, f'mask_{idx}.pt')
            torch.save(outputs.cpu(), output_file)

generate_unlabeled_masks(Unet_masker, unlabeledloader)

#unlabeled_masks = generate_unlabeled_masks(Unet_masker, unlabeledloader)
# Out:
# (Generating): 100%|██████████| 13000/13000 [16:04<00:00, 13.47it/s]

# %%
# !zip -r output_masks.zip output_masks
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: output_masks/mask_10475.pt (deflated 100%)
#   adding: output_masks/mask_5335.pt (deflated 100%)
#   adding: output_masks/mask_1983.pt (deflated 100%)
#   adding: output_masks/mask_5611.pt (deflated 100%)
#   adding: output_masks/mask_10779.pt (deflated 100%)
#   adding: output_masks/mask_12999.pt (deflated 100%)
#   adding: output_masks/mask_6739.pt (deflated 100%)
#   adding: output_masks/mask_1340.pt (deflated 100%)
#   adding: output_masks/mask_5360.pt (deflated 100%)
#   adding: output_masks/mask_3615.pt (deflated 100%)
#   adding: output_masks/mask_6834.pt (deflated 100%)
#   adding: output_masks/mask_2774.pt (deflated 100%)
#   adding: output_masks/mask_4160.pt (deflated 100%)
#   adding: output_masks/mask_4303.pt (deflated 100%)
#   adding: output_masks/mask_1050.pt (deflated 100%)
#   adding: output_masks/mask_9089.pt (deflated 100%)
#   adding: output_masks/mask_7280.pt (deflated 100%)
#   adding: output_masks/mask_3298.pt (deflated 100%)
#   adding: output_masks/mask_10042.pt (deflated 100%)
#   adding: output_masks/mask_3102.pt (deflated 100%)
#   adding: output_masks/mask_5253.pt (deflated 100%)
#   adding: output_masks/mask_12005.pt (deflated 100%)
#   adding: output_masks/mask_12607.pt (deflated 100%)
#   adding: output_masks/mask_4015.pt (deflated 100%)
#   adding: output_masks/mask_7896.pt (deflated 100%)
#   adding: output_masks/mask_862.pt (deflated 100%)
#   adding: output_masks/mask_7347.pt (deflated 100%)
#   adding: output_masks/mask_2975.pt (deflated 100%)
#   adding: output_masks/mask_3668.pt (deflated 100%)
#   adding: output_masks/mask_1813.pt (deflated 100%)
#   adding: output_masks/mask_11623.pt (deflated 100%)
#   adding: output_masks/mask_10647.pt (deflated 100%)
#   adding: output_masks/mask_2338.pt (deflated 100%)
#   adding: output_masks/mask_11264.pt (deflated 100%)
#   adding: output_masks/mask_2651.pt (deflated 100%)
#   adding: output_masks/mask_10579.pt (deflated 100%)
#   adding: output_masks/mask_7659.pt (deflated 100%)
#   adding: output_masks/mask_2009.pt (deflated 100%)
#   adding: output_masks/mask_801.pt (deflated 100%)
#   adding: output_masks/mask_9261.pt (deflated 100%)
#   adding: output_masks/mask_5271.pt (deflated 100%)
#   adding: output_masks/mask_7183.pt (deflated 100%)
#   adding: output_masks/mask_2489.pt (deflated 100%)
#   adding: output_masks/mask_1147.pt (deflated 100%)
#   adding: output_masks/mask_12092.pt (deflated 100%)
#   adding: output_masks/mask_2631.pt (deflated 100%)
#   adding: output_masks/mask_1644.pt (deflated 100%)
#   adding: output_masks/mask_7970.pt (deflated 100%)
#   adding: output_masks/mask_10277.pt (deflated 100%)
#   adding: output_masks/mask_8594.pt (deflated 100%)
#   adding: output_masks/mask_6606.pt (deflated 100%)
#   adding: output_masks/mask_4562.pt (deflated 100%)
#   adding: output_masks/mask_679.pt (deflated 100%)
#   adding: output_masks/mask_11431.pt (deflated 100%)
#   adding: output_masks/mask_4131.pt (deflated 100%)
#   adding: output_masks/mask_11484.pt (deflated 100%)
#   adding: output_masks/mask_9968.pt (deflated 100%)
#   adding: output_masks/mask_3216.pt (deflated 100%)
#   adding: output_masks/mask_7542.pt (deflated 100%)
#   adding: output_masks/mask_9333.pt (deflated 100%)
#   adding: output_masks/mask_7254.pt (deflated 100%)
#   adding: output_masks/mask_4506.pt (deflated 100%)
#   adding: output_masks/mask_10709.pt (deflated 100%)
#   adding: output_masks/mask_7917.pt (deflated 100%)
#   adding: output_masks/mask_11983.pt (deflated 100%)
#   adding: output_masks/mask_5114.pt (deflated 100%)
#   adding: output_masks/mask_12164.pt (deflated 100%)
#   adding: output_masks/mask_10816.pt (deflated 100%)
#   adding: output_masks/mask_10186.pt (deflated 100%)
#   adding: output_masks/mask_6367.pt (deflated 100%)
#   adding: output_masks/mask_9731.pt (deflated 100%)
#   adding: output_masks/mask_12976.pt (deflated 100%)
#   adding: output_masks/mask_112.pt (deflated 100%)
#   adding: output_masks/mask_12161.pt (deflated 100%)
#   adding: output_masks/mask_7759.pt (deflated 100%)
#   adding: output_masks/mask_3579.pt (deflated 100%)
#   adding: output_masks/mask_2677.pt (deflated 100%)
#   adding: output_masks/mask_11929.pt (deflated 100%)
#   adding: output_masks/mask_11954.pt (deflated 100%)
#   adding: output_masks/mask_7067.pt (deflated 100%)
#   adding: output_masks/mask_6460.pt (deflated 100%)
#   adding: output_masks/mask_1156.pt (deflated 100%)
#   adding: output_masks/mask_5557.pt (deflated 100%)
#   adding: output_masks/mask_8570.pt (deflated 100%)
#   adding: output_masks/mask_12806.pt (deflated 100%)
#   adding: output_masks/mask_2304.pt (deflated 100%)
#   adding: output_masks/mask_4950.pt (deflated 100%)
#   adding: output_masks/mask_2833.pt (deflated 100%)
#   adding: output_masks/mask_10060.pt (deflated 100%)
#   adding: output_masks/mask_2394.pt (deflated 100%)
#   adding: output_masks/mask_8244.pt (deflated 100%)
#   adding: output_masks/mask_10707.pt (deflated 100%)
#   adding: output_masks/mask_10238.pt (deflated 100%)
#   adding: output_masks/mask_2972.pt (deflated 100%)
#   adding: output_masks/mask_6267.pt (deflated 100%)
#   adding: output_masks/mask_1971.pt (deflated 100%)
#   adding: output_masks/mask_8075.pt (deflated 100%)
#   adding: output_masks/mask_2432.pt (deflated 100%)
#   adding: output_masks/mask_2490.pt (deflated 100%)
#   adding: output_masks/mask_4344.pt (deflated 100%)
#   adding: output_masks/mask_2624.pt (deflated 100%)
#   adding: output_masks/mask_1570.pt (deflated 100%)
#   adding: output_masks/mask_4052.pt (deflated 100%)
#   adding: output_masks/mask_9249.pt (deflated 100%)
#   adding: output_masks/mask_6181.pt (deflated 100%)
#   adding: output_masks/mask_2193.pt (deflated 100%)
#   adding: output_masks/mask_7767.pt (deflated 100%)
#   adding: output_masks/mask_2592.pt (deflated 100%)
#   adding: output_masks/mask_2370.pt (deflated 100%)
#   adding: output_masks/mask_10369.pt (deflated 100%)
#   adding: output_masks/mask_11991.pt (deflated 100%)
#   adding: output_masks/mask_3918.pt (deflated 100%)
#   adding: output_masks/mask_449.pt (deflated 100%)
#   adding: output_masks/mask_3162.pt (deflated 100%)
#   adding: output_masks/mask_6504.pt (deflated 100%)
#   adding: output_masks/mask_3437.pt (deflated 100%)
#   adding: output_masks/mask_1500.pt (deflated 100%)
#   adding: output_masks/mask_6854.pt (deflated 100%)
#   adding: output_masks/mask_4503.pt (deflated 100%)
#   adding: output_masks/mask_8171.pt (deflated 100%)
#   adding: output_masks/mask_11999.pt (deflated 100%)
#   adding: output_masks/mask_10168.pt (deflated 100%)
#   adding: output_masks/mask_7939.pt (deflated 100%)
#   adding: output_masks/mask_5622.pt (deflated 100%)
#   adding: output_masks/mask_3707.pt (deflated 100%)
#   adding: output_masks/mask_8917.pt (deflated 100%)
#   adding: output_masks/mask_5682.pt (deflated 100%)
#   adding: output_masks/mask_10443.pt (deflated 100%)
#   adding: output_masks/mask_11960.pt (deflated 100%)
#   adding: output_masks/mask_10582.pt (deflated 100%)
#   adding: output_masks/mask_3430.pt (deflated 100%)
#   adding: output_masks/mask_11819.pt (deflated 100%)
#   adding: output_masks/mask_12310.pt (deflated 100%)
#   adding: output_masks/mask_12159.pt (deflated 100%)
#   adding: output_masks/mask_9185.pt (deflated 100%)
#   adding: output_masks/mask_8404.pt (deflated 100%)
#   adding: output_masks/mask_6226.pt (deflated 100%)
#   adding: output_masks/mask_7180.pt (deflated 100%)
#   adding: output_masks/mask_6664.pt (deflated 100%)
#   adding: output_masks/mask_3921.pt (deflated 100%)
#   adding: output_masks/mask_7052.pt (deflated 100%)
#   adding: output_masks/mask_1469.pt (deflated 100%)
#   adding: output_masks/mask_9250.pt (deflated 100%)
#   adding: output_masks/mask_10209.pt (deflated 100%)
#   adding: output_masks/mask_3877.pt (deflated 100%)
#   adding: output_masks/mask_5499.pt (deflated 100%)
#   adding: output_masks/mask_7398.pt (deflated 100%)
#   adding: output_masks/mask_2483.pt (deflated 100%)
#   adding: output_masks/mask_4623.pt (deflated 100%)
#   adding: output_masks/mask_9393.pt (deflated 100%)
#   adding: output_masks/mask_4850.pt (deflated 100%)
#   adding: output_masks/mask_11645.pt (deflated 100%)
#   adding: output_masks/mask_8484.pt (deflated 100%)
#   adding: output_masks/mask_4502.pt (deflated 100%)
#   adding: output_masks/mask_9787.pt (deflated 100%)
#   adding: output_masks/mask_9427.pt (deflated 100%)
#   adding: output_masks/mask_9384.pt (deflated 100%)
#   adding: output_masks/mask_1024.pt (deflated 100%)
#   adding: output_masks/mask_9966.pt (deflated 100%)
#   adding: output_masks/mask_3622.pt (deflated 100%)
#   adding: output_masks/mask_9816.pt (deflated 100%)
#   adding: output_masks/mask_5888.pt (deflated 100%)
#   adding: output_masks/mask_12788.pt (deflated 100%)
#   adding: output_masks/mask_1974.pt (deflated 100%)
#   adding: output_masks/mask_1426.pt (deflated 100%)
#   adding: output_masks/mask_8699.pt (deflated 100%)
#   adding: output_masks/mask_12663.pt (deflated 100%)
#   adding: output_masks/mask_9588.pt (deflated 100%)
#   adding: output_masks/mask_6058.pt (deflated 100%)
#   adding: output_masks/mask_7492.pt (deflated 100%)
#   adding: output_masks/mask_5093.pt (deflated 100%)
#   adding: output_masks/mask_7786.pt (deflated 100%)
#   adding: output_masks/mask_10046.pt (deflated 100%)
#   adding: output_masks/mask_9843.pt (deflated 100%)
#   adding: output_masks/mask_9655.pt (deflated 100%)
#   adding: output_masks/mask_12269.pt (deflated 100%)
#   adding: output_masks/mask_6121.pt (deflated 100%)
#   adding: output_masks/mask_2757.pt (deflated 100%)
#   adding: output_masks/mask_12754.pt (deflated 100%)
#   adding: output_masks/mask_9542.pt (deflated 100%)
#   adding: output_masks/mask_4633.pt (deflated 100%)
#   adding: output_masks/mask_12347.pt (deflated 100%)
#   adding: output_masks/mask_6145.pt (deflated 100%)
#   adding: output_masks/mask_10408.pt (deflated 100%)
#   adding: output_masks/mask_12947.pt (deflated 100%)
#   adding: output_masks/mask_5205.pt (deflated 100%)
#   adding: output_masks/mask_11562.pt (deflated 100%)
#   adding: output_masks/mask_11626.pt (deflated 100%)
#   adding: output_masks/mask_7867.pt (deflated 100%)
#   adding: output_masks/mask_11057.pt (deflated 100%)
#   adding: output_masks/mask_12203.pt (deflated 100%)
#   adding: output_masks/mask_7374.pt (deflated 100%)
#   adding: output_masks/mask_3071.pt (deflated 100%)
#   adding: output_masks/mask_566.pt (deflated 100%)
#   adding: output_masks/mask_11774.pt (deflated 100%)
#   adding: output_masks/mask_8773.pt (deflated 100%)
#   adding: output_masks/mask_11493.pt (deflated 100%)
#   adding: output_masks/mask_2487.pt (deflated 100%)
#   adding: output_masks/mask_1022.pt (deflated 100%)
#   adding: output_masks/mask_3138.pt (deflated 100%)
#   adding: output_masks/mask_324.pt (deflated 100%)
#   adding: output_masks/mask_5526.pt (deflated 100%)
#   adding: output_masks/mask_11425.pt (deflated 100%)
#   adding: output_masks/mask_7305.pt (deflated 100%)
#   adding: output_masks/mask_1394.pt (deflated 100%)
#   adding: output_masks/mask_11012.pt (deflated 100%)
#   adding: output_masks/mask_2658.pt (deflated 100%)
#   adding: output_masks/mask_2946.pt (deflated 100%)
#   adding: output_masks/mask_374.pt (deflated 100%)
#   adding: output_masks/mask_9896.pt (deflated 100%)
#   adding: output_masks/mask_9236.pt (deflated 100%)
#   adding: output_masks/mask_1487.pt (deflated 100%)
#   adding: output_masks/mask_6911.pt (deflated 100%)
#   adding: output_masks/mask_12821.pt (deflated 100%)
#   adding: output_masks/mask_10320.pt (deflated 100%)
#   adding: output_masks/mask_4923.pt (deflated 100%)
#   adding: output_masks/mask_2911.pt (deflated 100%)
#   adding: output_masks/mask_12306.pt (deflated 100%)
#   adding: output_masks/mask_2504.pt (deflated 100%)
#   adding: output_masks/mask_12154.pt (deflated 100%)
#   adding: output_masks/mask_4246.pt (deflated 100%)
#   adding: output_masks/mask_6493.pt (deflated 100%)
#   adding: output_masks/mask_12130.pt (deflated 100%)
#   adding: output_masks/mask_12909.pt (deflated 100%)
#   adding: output_masks/mask_7298.pt (deflated 100%)
#   adding: output_masks/mask_1198.pt (deflated 100%)
#   adding: output_masks/mask_189.pt (deflated 100%)
#   adding: output_masks/mask_10446.pt (deflated 100%)
#   adding: output_masks/mask_5215.pt (deflated 100%)
#   adding: output_masks/mask_5482.pt (deflated 100%)
#   adding: output_masks/mask_1680.pt (deflated 100%)
#   adding: output_masks/mask_8439.pt (deflated 100%)
#   adding: output_masks/mask_7405.pt (deflated 100%)
#   adding: output_masks/mask_10273.pt (deflated 100%)
#   adding: output_masks/mask_12743.pt (deflated 100%)
#   adding: output_masks/mask_2359.pt (deflated 100%)
#   adding: output_masks/mask_3826.pt (deflated 100%)
#   adding: output_masks/mask_3113.pt (deflated 100%)
#   adding: output_masks/mask_9900.pt (deflated 100%)
#   adding: output_masks/mask_12574.pt (deflated 100%)
#   adding: output_masks/mask_8748.pt (deflated 100%)
#   adding: output_masks/mask_2657.pt (deflated 100%)
#   adding: output_masks/mask_11616.pt (deflated 100%)
#   adding: output_masks/mask_3514.pt (deflated 100%)
#   adding: output_masks/mask_4428.pt (deflated 100%)
#   adding: output_masks/mask_8200.pt (deflated 100%)
#   adding: output_masks/mask_3856.pt (deflated 100%)
#   adding: output_masks/mask_9803.pt (deflated 100%)
#   adding: output_masks/mask_144.pt (deflated 100%)
#   adding: output_masks/mask_4632.pt (deflated 100%)
#   adding: output_masks/mask_8529.pt (deflated 100%)
#   adding: output_masks/mask_12799.pt (deflated 100%)
#   adding: output_masks/mask_5245.pt (deflated 100%)
#   adding: output_masks/mask_3692.pt (deflated 100%)
#   adding: output_masks/mask_942.pt (deflated 100%)
#   adding: output_masks/mask_7691.pt (deflated 100%)
#   adding: output_masks/mask_8814.pt (deflated 100%)
#   adding: output_masks/mask_7621.pt (deflated 100%)
#   adding: output_masks/mask_1776.pt (deflated 100%)
#   adding: output_masks/mask_9457.pt (deflated 100%)
#   adding: output_masks/mask_5368.pt (deflated 100%)
#   adding: output_masks/mask_7394.pt (deflated 100%)
#   adding: output_masks/mask_11994.pt (deflated 100%)
#   adding: output_masks/mask_4436.pt (deflated 100%)
#   adding: output_masks/mask_10918.pt (deflated 100%)
#   adding: output_masks/mask_7983.pt (deflated 100%)
#   adding: output_masks/mask_10565.pt (deflated 100%)
#   adding: output_masks/mask_7762.pt (deflated 100%)
#   adding: output_masks/mask_5951.pt (deflated 100%)
#   adding: output_masks/mask_8916.pt (deflated 100%)
#   adding: output_masks/mask_513.pt (deflated 100%)
#   adding: output_masks/mask_10859.pt (deflated 100%)
#   adding: output_masks/mask_5173.pt (deflated 100%)
#   adding: output_masks/mask_12618.pt (deflated 100%)
#   adding: output_masks/mask_5708.pt (deflated 100%)
#   adding: output_masks/mask_10734.pt (deflated 100%)
#   adding: output_masks/mask_1170.pt (deflated 100%)
#   adding: output_masks/mask_11729.pt (deflated 100%)
#   adding: output_masks/mask_10901.pt (deflated 100%)
#   adding: output_masks/mask_5097.pt (deflated 100%)
#   adding: output_masks/mask_10680.pt (deflated 100%)
#   adding: output_masks/mask_9499.pt (deflated 100%)
#   adding: output_masks/mask_2881.pt (deflated 100%)
#   adding: output_masks/mask_11981.pt (deflated 100%)
#   adding: output_masks/mask_1652.pt (deflated 100%)
#   adding: output_masks/mask_4895.pt (deflated 100%)
#   adding: output_masks/mask_5714.pt (deflated 100%)
#   adding: output_masks/mask_10204.pt (deflated 100%)
#   adding: output_masks/mask_1852.pt (deflated 100%)
#   adding: output_masks/mask_11507.pt (deflated 100%)
#   adding: output_masks/mask_7250.pt (deflated 100%)
#   adding: output_masks/mask_2756.pt (deflated 100%)
#   adding: output_masks/mask_10011.pt (deflated 100%)
#   adding: output_masks/mask_206.pt (deflated 100%)
#   adding: output_masks/mask_5067.pt (deflated 100%)
#   adding: output_masks/mask_12218.pt (deflated 100%)
#   adding: output_masks/mask_5894.pt (deflated 100%)
#   adding: output_masks/mask_8725.pt (deflated 100%)
#   adding: output_masks/mask_1882.pt (deflated 100%)
#   adding: output_masks/mask_3645.pt (deflated 100%)
#   adding: output_masks/mask_11275.pt (deflated 100%)
#   adding: output_masks/mask_2369.pt (deflated 100%)
#   adding: output_masks/mask_11294.pt (deflated 100%)
#   adding: output_masks/mask_9988.pt (deflated 100%)
#   adding: output_masks/mask_5447.pt (deflated 100%)
#   adding: output_masks/mask_12114.pt (deflated 100%)
#   adding: output_masks/mask_6264.pt (deflated 100%)
#   adding: output_masks/mask_3017.pt (deflated 100%)
#   adding: output_masks/mask_6401.pt (deflated 100%)
#   adding: output_masks/mask_1494.pt (deflated 100%)
#   adding: output_masks/mask_6463.pt (deflated 100%)
#   adding: output_masks/mask_12049.pt (deflated 100%)
#   adding: output_masks/mask_11181.pt (deflated 100%)
#   adding: output_masks/mask_2955.pt (deflated 100%)
#   adding: output_masks/mask_18.pt (deflated 100%)
#   adding: output_masks/mask_8007.pt (deflated 100%)
#   adding: output_masks/mask_1959.pt (deflated 100%)
#   adding: output_masks/mask_6688.pt (deflated 100%)
#   adding: output_masks/mask_3190.pt (deflated 100%)
#   adding: output_masks/mask_8223.pt (deflated 100%)
#   adding: output_masks/mask_2520.pt (deflated 100%)
#   adding: output_masks/mask_9344.pt (deflated 100%)
#   adding: output_masks/mask_2263.pt (deflated 100%)
#   adding: output_masks/mask_4671.pt (deflated 100%)
#   adding: output_masks/mask_5885.pt (deflated 100%)
#   adding: output_masks/mask_5517.pt (deflated 100%)
#   adding: output_masks/mask_4296.pt (deflated 100%)
#   adding: output_masks/mask_1053.pt (deflated 100%)
#   adding: output_masks/mask_3149.pt (deflated 100%)
#   adding: output_masks/mask_707.pt (deflated 100%)
#   adding: output_masks/mask_7228.pt (deflated 100%)
#   adding: output_masks/mask_7895.pt (deflated 100%)
#   adding: output_masks/mask_9507.pt (deflated 100%)
#   adding: output_masks/mask_8681.pt (deflated 100%)
#   adding: output_masks/mask_4203.pt (deflated 100%)
#   adding: output_masks/mask_10774.pt (deflated 100%)
#   adding: output_masks/mask_1489.pt (deflated 100%)
#   adding: output_masks/mask_1164.pt (deflated 100%)
#   adding: output_masks/mask_220.pt (deflated 100%)
#   adding: output_masks/mask_8381.pt (deflated 100%)
#   adding: output_masks/mask_9157.pt (deflated 100%)
#   adding: output_masks/mask_5323.pt (deflated 100%)
#   adding: output_masks/mask_9679.pt (deflated 100%)
#   adding: output_masks/mask_11139.pt (deflated 100%)
#   adding: output_masks/mask_9275.pt (deflated 100%)
#   adding: output_masks/mask_6787.pt (deflated 100%)
#   adding: output_masks/mask_10130.pt (deflated 100%)
#   adding: output_masks/mask_5848.pt (deflated 100%)
#   adding: output_masks/mask_1600.pt (deflated 100%)
#   adding: output_masks/mask_9951.pt (deflated 100%)
#   adding: output_masks/mask_7315.pt (deflated 100%)
#   adding: output_masks/mask_1290.pt (deflated 100%)
#   adding: output_masks/mask_10497.pt (deflated 100%)
#   adding: output_masks/mask_5740.pt (deflated 100%)
#   adding: output_masks/mask_2417.pt (deflated 100%)
#   adding: output_masks/mask_1444.pt (deflated 100%)
#   adding: output_masks/mask_10458.pt (deflated 100%)
#   adding: output_masks/mask_8213.pt (deflated 100%)
#   adding: output_masks/mask_9114.pt (deflated 100%)
#   adding: output_masks/mask_2654.pt (deflated 100%)
#   adding: output_masks/mask_5818.pt (deflated 100%)
#   adding: output_masks/mask_6791.pt (deflated 100%)
#   adding: output_masks/mask_4877.pt (deflated 100%)
#   adding: output_masks/mask_8379.pt (deflated 100%)
#   adding: output_masks/mask_3047.pt (deflated 100%)
#   adding: output_masks/mask_2202.pt (deflated 100%)
#   adding: output_masks/mask_3540.pt (deflated 100%)
#   adding: output_masks/mask_3477.pt (deflated 100%)
#   adding: output_masks/mask_11553.pt (deflated 100%)
#   adding: output_masks/mask_8674.pt (deflated 100%)
#   adding: output_masks/mask_10025.pt (deflated 100%)
#   adding: output_masks/mask_6617.pt (deflated 100%)
#   adding: output_masks/mask_1632.pt (deflated 100%)
#   adding: output_masks/mask_12927.pt (deflated 100%)
#   adding: output_masks/mask_1558.pt (deflated 100%)
#   adding: output_masks/mask_3011.pt (deflated 100%)
#   adding: output_masks/mask_2059.pt (deflated 100%)
#   adding: output_masks/mask_8573.pt (deflated 100%)
#   adding: output_masks/mask_9586.pt (deflated 100%)
#   adding: output_masks/mask_7634.pt (deflated 100%)
#   adding: output_masks/mask_11732.pt (deflated 100%)
#   adding: output_masks/mask_6234.pt (deflated 100%)
#   adding: output_masks/mask_2862.pt (deflated 100%)
#   adding: output_masks/mask_12110.pt (deflated 100%)
#   adding: output_masks/mask_4321.pt (deflated 100%)
#   adding: output_masks/mask_8141.pt (deflated 100%)
#   adding: output_masks/mask_11464.pt (deflated 100%)
#   adding: output_masks/mask_12893.pt (deflated 100%)
#   adding: output_masks/mask_5919.pt (deflated 100%)
#   adding: output_masks/mask_6587.pt (deflated 100%)
#   adding: output_masks/mask_8352.pt (deflated 100%)
#   adding: output_masks/mask_9948.pt (deflated 100%)
#   adding: output_masks/mask_9102.pt (deflated 100%)
#   adding: output_masks/mask_5933.pt (deflated 100%)
#   adding: output_masks/mask_10532.pt (deflated 100%)
#   adding: output_masks/mask_4387.pt (deflated 100%)
#   adding: output_masks/mask_1607.pt (deflated 100%)
#   adding: output_masks/mask_11408.pt (deflated 100%)
#   adding: output_masks/mask_308.pt (deflated 100%)
#   adding: output_masks/mask_4653.pt (deflated 100%)
#   adding: output_masks/mask_357.pt (deflated 100%)
#   adding: output_masks/mask_8298.pt (deflated 100%)
#   adding: output_masks/mask_5693.pt (deflated 100%)
#   adding: output_masks/mask_936.pt (deflated 100%)
#   adding: output_masks/mask_8889.pt (deflated 100%)
#   adding: output_masks/mask_6462.pt (deflated 100%)
#   adding: output_masks/mask_9754.pt (deflated 100%)
#   adding: output_masks/mask_7494.pt (deflated 100%)
#   adding: output_masks/mask_4926.pt (deflated 100%)
#   adding: output_masks/mask_10199.pt (deflated 100%)
#   adding: output_masks/mask_9088.pt (deflated 100%)
#   adding: output_masks/mask_2.pt (deflated 100%)
#   adding: output_masks/mask_633.pt (deflated 100%)
#   adding: output_masks/mask_7099.pt (deflated 100%)
#   adding: output_masks/mask_6278.pt (deflated 100%)
#   adding: output_masks/mask_2762.pt (deflated 100%)
#   adding: output_masks/mask_8613.pt (deflated 100%)
#   adding: output_masks/mask_2217.pt (deflated 100%)
#   adding: output_masks/mask_2146.pt (deflated 100%)
#   adding: output_masks/mask_530.pt (deflated 100%)
#   adding: output_masks/mask_10179.pt (deflated 100%)
#   adding: output_masks/mask_8643.pt (deflated 100%)
#   adding: output_masks/mask_8163.pt (deflated 100%)
#   adding: output_masks/mask_7818.pt (deflated 100%)
#   adding: output_masks/mask_10784.pt (deflated 100%)
#   adding: output_masks/mask_4717.pt (deflated 100%)
#   adding: output_masks/mask_7457.pt (deflated 100%)
#   adding: output_masks/mask_3957.pt (deflated 100%)
#   adding: output_masks/mask_3876.pt (deflated 100%)
#   adding: output_masks/mask_10875.pt (deflated 100%)
#   adding: output_masks/mask_1120.pt (deflated 100%)
#   adding: output_masks/mask_10913.pt (deflated 100%)
#   adding: output_masks/mask_6252.pt (deflated 100%)
#   adding: output_masks/mask_6078.pt (deflated 100%)
#   adding: output_masks/mask_716.pt (deflated 100%)
#   adding: output_masks/mask_11232.pt (deflated 100%)
#   adding: output_masks/mask_10860.pt (deflated 100%)
#   adding: output_masks/mask_6637.pt (deflated 100%)
#   adding: output_masks/mask_12885.pt (deflated 100%)
#   adding: output_masks/mask_9306.pt (deflated 100%)
#   adding: output_masks/mask_8808.pt (deflated 100%)
#   adding: output_masks/mask_6223.pt (deflated 100%)
#   adding: output_masks/mask_11325.pt (deflated 100%)
#   adding: output_masks/mask_7103.pt (deflated 100%)
#   adding: output_masks/mask_5803.pt (deflated 100%)
#   adding: output_masks/mask_1609.pt (deflated 100%)
#   adding: output_masks/mask_10715.pt (deflated 100%)
#   adding: output_masks/mask_2050.pt (deflated 100%)
#   adding: output_masks/mask_632.pt (deflated 100%)
#   adding: output_masks/mask_2466.pt (deflated 100%)
#   adding: output_masks/mask_6969.pt (deflated 100%)
#   adding: output_masks/mask_5025.pt (deflated 100%)
#   adding: output_masks/mask_2858.pt (deflated 100%)
#   adding: output_masks/mask_8155.pt (deflated 100%)
#   adding: output_masks/mask_3563.pt (deflated 100%)
#   adding: output_masks/mask_7518.pt (deflated 100%)
#   adding: output_masks/mask_3935.pt (deflated 100%)
#   adding: output_masks/mask_1392.pt (deflated 100%)
#   adding: output_masks/mask_2700.pt (deflated 100%)
#   adding: output_masks/mask_4975.pt (deflated 100%)
#   adding: output_masks/mask_6020.pt (deflated 100%)
#   adding: output_masks/mask_7084.pt (deflated 100%)
#   adding: output_masks/mask_5263.pt (deflated 100%)
#   adding: output_masks/mask_309.pt (deflated 100%)
#   adding: output_masks/mask_1129.pt (deflated 100%)
#   adding: output_masks/mask_12070.pt (deflated 100%)
#   adding: output_masks/mask_7993.pt (deflated 100%)
#   adding: output_masks/mask_5430.pt (deflated 100%)
#   adding: output_masks/mask_9741.pt (deflated 100%)
#   adding: output_masks/mask_11829.pt (deflated 100%)
#   adding: output_masks/mask_7465.pt (deflated 100%)
#   adding: output_masks/mask_8711.pt (deflated 100%)
#   adding: output_masks/mask_1539.pt (deflated 100%)
#   adding: output_masks/mask_4050.pt (deflated 100%)
#   adding: output_masks/mask_10616.pt (deflated 100%)
#   adding: output_masks/mask_8521.pt (deflated 100%)
#   adding: output_masks/mask_12676.pt (deflated 100%)
#   adding: output_masks/mask_9118.pt (deflated 100%)
#   adding: output_masks/mask_756.pt (deflated 100%)
#   adding: output_masks/mask_1754.pt (deflated 100%)
#   adding: output_masks/mask_8601.pt (deflated 100%)
#   adding: output_masks/mask_4097.pt (deflated 100%)
#   adding: output_masks/mask_12812.pt (deflated 100%)
#   adding: output_masks/mask_11378.pt (deflated 100%)
#   adding: output_masks/mask_8112.pt (deflated 100%)
#   adding: output_masks/mask_3090.pt (deflated 100%)
#   adding: output_masks/mask_504.pt (deflated 100%)
#   adding: output_masks/mask_7119.pt (deflated 100%)
#   adding: output_masks/mask_4020.pt (deflated 100%)
#   adding: output_masks/mask_6887.pt (deflated 100%)
#   adding: output_masks/mask_5845.pt (deflated 100%)
#   adding: output_masks/mask_9641.pt (deflated 100%)
#   adding: output_masks/mask_9993.pt (deflated 100%)
#   adding: output_masks/mask_1184.pt (deflated 100%)
#   adding: output_masks/mask_7389.pt (deflated 100%)
#   adding: output_masks/mask_3405.pt (deflated 100%)
#   adding: output_masks/mask_10167.pt (deflated 100%)
#   adding: output_masks/mask_4212.pt (deflated 100%)
#   adding: output_masks/mask_4951.pt (deflated 100%)
#   adding: output_masks/mask_10858.pt (deflated 100%)
#   adding: output_masks/mask_7651.pt (deflated 100%)
#   adding: output_masks/mask_2100.pt (deflated 100%)
#   adding: output_masks/mask_11308.pt (deflated 100%)
#   adding: output_masks/mask_2786.pt (deflated 100%)
#   adding: output_masks/mask_631.pt (deflated 100%)
#   adding: output_masks/mask_7766.pt (deflated 100%)
#   adding: output_masks/mask_1525.pt (deflated 100%)
#   adding: output_masks/mask_8984.pt (deflated 100%)
#   adding: output_masks/mask_973.pt (deflated 100%)
#   adding: output_masks/mask_4156.pt (deflated 100%)
#   adding: output_masks/mask_8343.pt (deflated 100%)
#   adding: output_masks/mask_2166.pt (deflated 100%)
#   adding: output_masks/mask_8230.pt (deflated 100%)
#   adding: output_masks/mask_6249.pt (deflated 100%)
#   adding: output_masks/mask_12311.pt (deflated 100%)
#   adding: output_masks/mask_143.pt (deflated 100%)
#   adding: output_masks/mask_7197.pt (deflated 100%)
#   adding: output_masks/mask_1928.pt (deflated 100%)
#   adding: output_masks/mask_4541.pt (deflated 100%)
#   adding: output_masks/mask_3763.pt (deflated 100%)
#   adding: output_masks/mask_3602.pt (deflated 100%)
#   adding: output_masks/mask_6103.pt (deflated 100%)
#   adding: output_masks/mask_0.pt (deflated 100%)
#   adding: output_masks/mask_2699.pt (deflated 100%)
#   adding: output_masks/mask_6485.pt (deflated 100%)
#   adding: output_masks/mask_12342.pt (deflated 100%)
#   adding: output_masks/mask_9108.pt (deflated 100%)
#   adding: output_masks/mask_6591.pt (deflated 100%)
#   adding: output_masks/mask_12426.pt (deflated 100%)
#   adding: output_masks/mask_8687.pt (deflated 100%)
#   adding: output_masks/mask_9840.pt (deflated 100%)
#   adding: output_masks/mask_3882.pt (deflated 100%)
#   adding: output_masks/mask_4467.pt (deflated 100%)
#   adding: output_masks/mask_3538.pt (deflated 100%)
#   adding: output_masks/mask_5490.pt (deflated 100%)
#   adding: output_masks/mask_10208.pt (deflated 100%)
#   adding: output_masks/mask_5769.pt (deflated 100%)
#   adding: output_masks/mask_3074.pt (deflated 100%)
#   adding: output_masks/mask_856.pt (deflated 100%)
#   adding: output_masks/mask_12304.pt (deflated 100%)
#   adding: output_masks/mask_154.pt (deflated 100%)
#   adding: output_masks/mask_1135.pt (deflated 100%)
#   adding: output_masks/mask_2758.pt (deflated 100%)
#   adding: output_masks/mask_2908.pt (deflated 100%)
#   adding: output_masks/mask_11045.pt (deflated 100%)
#   adding: output_masks/mask_8169.pt (deflated 100%)
#   adding: output_masks/mask_2868.pt (deflated 100%)
#   adding: output_masks/mask_10388.pt (deflated 100%)
#   adding: output_masks/mask_3171.pt (deflated 100%)
#   adding: output_masks/mask_5665.pt (deflated 100%)
#   adding: output_masks/mask_9873.pt (deflated 100%)
#   adding: output_masks/mask_7657.pt (deflated 100%)
#   adding: output_masks/mask_2385.pt (deflated 100%)
#   adding: output_masks/mask_6276.pt (deflated 100%)
#   adding: output_masks/mask_5088.pt (deflated 100%)
#   adding: output_masks/mask_2041.pt (deflated 100%)
#   adding: output_masks/mask_10247.pt (deflated 100%)
#   adding: output_masks/mask_1092.pt (deflated 100%)
#   adding: output_masks/mask_6073.pt (deflated 100%)
#   adding: output_masks/mask_3165.pt (deflated 100%)
#   adding: output_masks/mask_12462.pt (deflated 100%)
#   adding: output_masks/mask_8690.pt (deflated 100%)
#   adding: output_masks/mask_1642.pt (deflated 100%)
#   adding: output_masks/mask_9197.pt (deflated 100%)
#   adding: output_masks/mask_5675.pt (deflated 100%)
#   adding: output_masks/mask_8595.pt (deflated 100%)
#   adding: output_masks/mask_6889.pt (deflated 100%)
#   adding: output_masks/mask_4979.pt (deflated 100%)
#   adding: output_masks/mask_11350.pt (deflated 100%)
#   adding: output_masks/mask_762.pt (deflated 100%)
#   adding: output_masks/mask_11665.pt (deflated 100%)
#   adding: output_masks/mask_11333.pt (deflated 100%)
#   adding: output_masks/mask_2243.pt (deflated 100%)
#   adding: output_masks/mask_4144.pt (deflated 100%)
#   adding: output_masks/mask_3679.pt (deflated 100%)
#   adding: output_masks/mask_4901.pt (deflated 100%)
#   adding: output_masks/mask_200.pt (deflated 100%)
#   adding: output_masks/mask_9657.pt (deflated 100%)
#   adding: output_masks/mask_4563.pt (deflated 100%)
#   adding: output_masks/mask_9265.pt (deflated 100%)
#   adding: output_masks/mask_1079.pt (deflated 100%)
#   adding: output_masks/mask_3501.pt (deflated 100%)
#   adding: output_masks/mask_2601.pt (deflated 100%)
#   adding: output_masks/mask_12912.pt (deflated 100%)
#   adding: output_masks/mask_6098.pt (deflated 100%)
#   adding: output_masks/mask_3984.pt (deflated 100%)
#   adding: output_masks/mask_5946.pt (deflated 100%)
#   adding: output_masks/mask_12697.pt (deflated 100%)
#   adding: output_masks/mask_10448.pt (deflated 100%)
#   adding: output_masks/mask_3352.pt (deflated 100%)
#   adding: output_masks/mask_11489.pt (deflated 100%)
#   adding: output_masks/mask_8482.pt (deflated 100%)
#   adding: output_masks/mask_8191.pt (deflated 100%)
#   adding: output_masks/mask_6752.pt (deflated 100%)
#   adding: output_masks/mask_6293.pt (deflated 100%)
#   adding: output_masks/mask_11946.pt (deflated 100%)
#   adding: output_masks/mask_11386.pt (deflated 100%)
#   adding: output_masks/mask_9740.pt (deflated 100%)
#   adding: output_masks/mask_6765.pt (deflated 100%)
#   adding: output_masks/mask_10367.pt (deflated 100%)
#   adding: output_masks/mask_8782.pt (deflated 100%)
#   adding: output_masks/mask_11890.pt (deflated 100%)
#   adding: output_masks/mask_7739.pt (deflated 100%)
#   adding: output_masks/mask_12086.pt (deflated 100%)
#   adding: output_masks/mask_9582.pt (deflated 100%)
#   adding: output_masks/mask_3276.pt (deflated 100%)
#   adding: output_masks/mask_2704.pt (deflated 100%)
#   adding: output_masks/mask_2349.pt (deflated 100%)
#   adding: output_masks/mask_2755.pt (deflated 100%)
#   adding: output_masks/mask_6718.pt (deflated 100%)
#   adding: output_masks/mask_7447.pt (deflated 100%)
#   adding: output_masks/mask_12319.pt (deflated 100%)
#   adding: output_masks/mask_1416.pt (deflated 100%)
#   adding: output_masks/mask_11018.pt (deflated 100%)
#   adding: output_masks/mask_2314.pt (deflated 100%)
#   adding: output_masks/mask_11455.pt (deflated 100%)
#   adding: output_masks/mask_4285.pt (deflated 100%)
#   adding: output_masks/mask_10298.pt (deflated 100%)
#   adding: output_masks/mask_1361.pt (deflated 100%)
#   adding: output_masks/mask_8455.pt (deflated 100%)
#   adding: output_masks/mask_4580.pt (deflated 100%)
#   adding: output_masks/mask_6354.pt (deflated 100%)
#   adding: output_masks/mask_7384.pt (deflated 100%)
#   adding: output_masks/mask_12572.pt (deflated 100%)
#   adding: output_masks/mask_488.pt (deflated 100%)
#   adding: output_masks/mask_4167.pt (deflated 100%)
#   adding: output_masks/mask_12867.pt (deflated 100%)
#   adding: output_masks/mask_8042.pt (deflated 100%)
#   adding: output_masks/mask_8880.pt (deflated 100%)
#   adding: output_masks/mask_7338.pt (deflated 100%)
#   adding: output_masks/mask_9685.pt (deflated 100%)
#   adding: output_masks/mask_8205.pt (deflated 100%)
#   adding: output_masks/mask_3621.pt (deflated 100%)
#   adding: output_masks/mask_6919.pt (deflated 100%)
#   adding: output_masks/mask_6921.pt (deflated 100%)
#   adding: output_masks/mask_10083.pt (deflated 100%)
#   adding: output_masks/mask_1547.pt (deflated 100%)
#   adding: output_masks/mask_3891.pt (deflated 100%)
#   adding: output_masks/mask_1018.pt (deflated 100%)
#   adding: output_masks/mask_6259.pt (deflated 100%)
#   adding: output_masks/mask_5784.pt (deflated 100%)
#   adding: output_masks/mask_9771.pt (deflated 100%)
#   adding: output_masks/mask_11419.pt (deflated 100%)
#   adding: output_masks/mask_5645.pt (deflated 100%)
#   adding: output_masks/mask_2890.pt (deflated 100%)
#   adding: output_masks/mask_12477.pt (deflated 100%)
#   adding: output_masks/mask_9353.pt (deflated 100%)
#   adding: output_masks/mask_6483.pt (deflated 100%)
#   adding: output_masks/mask_9209.pt (deflated 100%)
#   adding: output_masks/mask_9361.pt (deflated 100%)
#   adding: output_masks/mask_2791.pt (deflated 100%)
#   adding: output_masks/mask_11822.pt (deflated 100%)
#   adding: output_masks/mask_4019.pt (deflated 100%)
#   adding: output_masks/mask_6842.pt (deflated 100%)
#   adding: output_masks/mask_12165.pt (deflated 100%)
#   adding: output_masks/mask_1027.pt (deflated 100%)
#   adding: output_masks/mask_10481.pt (deflated 100%)
#   adding: output_masks/mask_2492.pt (deflated 100%)
#   adding: output_masks/mask_965.pt (deflated 100%)
#   adding: output_masks/mask_1661.pt (deflated 100%)
#   adding: output_masks/mask_9916.pt (deflated 100%)
#   adding: output_masks/mask_3954.pt (deflated 100%)
#   adding: output_masks/mask_12213.pt (deflated 100%)
#   adding: output_masks/mask_219.pt (deflated 100%)
#   adding: output_masks/mask_5188.pt (deflated 100%)
#   adding: output_masks/mask_958.pt (deflated 100%)
#   adding: output_masks/mask_10302.pt (deflated 100%)
#   adding: output_masks/mask_6511.pt (deflated 100%)
#   adding: output_masks/mask_5392.pt (deflated 100%)
#   adding: output_masks/mask_4294.pt (deflated 100%)
#   adding: output_masks/mask_3789.pt (deflated 100%)
#   adding: output_masks/mask_3786.pt (deflated 100%)
#   adding: output_masks/mask_1718.pt (deflated 100%)
#   adding: output_masks/mask_1145.pt (deflated 100%)
#   adding: output_masks/mask_4354.pt (deflated 100%)
#   adding: output_masks/mask_4411.pt (deflated 100%)
#   adding: output_masks/mask_4549.pt (deflated 100%)
#   adding: output_masks/mask_6514.pt (deflated 100%)
#   adding: output_masks/mask_8680.pt (deflated 100%)
#   adding: output_masks/mask_10352.pt (deflated 100%)
#   adding: output_masks/mask_9571.pt (deflated 100%)
#   adding: output_masks/mask_10305.pt (deflated 100%)
#   adding: output_masks/mask_1273.pt (deflated 100%)
#   adding: output_masks/mask_2403.pt (deflated 100%)
#   adding: output_masks/mask_4610.pt (deflated 100%)
#   adding: output_masks/mask_6086.pt (deflated 100%)
#   adding: output_masks/mask_5417.pt (deflated 100%)
#   adding: output_masks/mask_2422.pt (deflated 100%)
#   adding: output_masks/mask_11172.pt (deflated 100%)
#   adding: output_masks/mask_12508.pt (deflated 100%)
#   adding: output_masks/mask_9054.pt (deflated 100%)
#   adding: output_masks/mask_11079.pt (deflated 100%)
#   adding: output_masks/mask_1086.pt (deflated 100%)
#   adding: output_masks/mask_4288.pt (deflated 100%)
#   adding: output_masks/mask_12935.pt (deflated 100%)
#   adding: output_masks/mask_7506.pt (deflated 100%)
#   adding: output_masks/mask_8925.pt (deflated 100%)
#   adding: output_masks/mask_3258.pt (deflated 100%)
#   adding: output_masks/mask_4685.pt (deflated 100%)
#   adding: output_masks/mask_12813.pt (deflated 100%)
#   adding: output_masks/mask_5328.pt (deflated 100%)
#   adding: output_masks/mask_9314.pt (deflated 100%)
#   adding: output_masks/mask_5257.pt (deflated 100%)
#   adding: output_masks/mask_278.pt (deflated 100%)
#   adding: output_masks/mask_3248.pt (deflated 100%)
#   adding: output_masks/mask_9826.pt (deflated 100%)
#   adding: output_masks/mask_8294.pt (deflated 100%)
#   adding: output_masks/mask_6050.pt (deflated 100%)
#   adding: output_masks/mask_4550.pt (deflated 100%)
#   adding: output_masks/mask_10000.pt (deflated 100%)
#   adding: output_masks/mask_1564.pt (deflated 100%)
#   adding: output_masks/mask_485.pt (deflated 100%)
#   adding: output_masks/mask_11948.pt (deflated 100%)
#   adding: output_masks/mask_4395.pt (deflated 100%)
#   adding: output_masks/mask_7005.pt (deflated 100%)
#   adding: output_masks/mask_2730.pt (deflated 100%)
#   adding: output_masks/mask_1853.pt (deflated 100%)
#   adding: output_masks/mask_6820.pt (deflated 100%)
#   adding: output_masks/mask_6418.pt (deflated 100%)
#   adding: output_masks/mask_6841.pt (deflated 100%)
#   adding: output_masks/mask_6.pt (deflated 100%)
#   adding: output_masks/mask_790.pt (deflated 100%)
#   adding: output_masks/mask_1099.pt (deflated 100%)
#   adding: output_masks/mask_10286.pt (deflated 100%)
#   adding: output_masks/mask_11548.pt (deflated 100%)
#   adding: output_masks/mask_6689.pt (deflated 100%)
#   adding: output_masks/mask_2694.pt (deflated 100%)
#   adding: output_masks/mask_6133.pt (deflated 100%)
#   adding: output_masks/mask_164.pt (deflated 100%)
#   adding: output_masks/mask_5118.pt (deflated 100%)
#   adding: output_masks/mask_271.pt (deflated 100%)
#   adding: output_masks/mask_1402.pt (deflated 100%)
#   adding: output_masks/mask_3268.pt (deflated 100%)
#   adding: output_masks/mask_1294.pt (deflated 100%)
#   adding: output_masks/mask_11906.pt (deflated 100%)
#   adding: output_masks/mask_10324.pt (deflated 100%)
#   adding: output_masks/mask_2486.pt (deflated 100%)
#   adding: output_masks/mask_2664.pt (deflated 100%)
#   adding: output_masks/mask_1140.pt (deflated 100%)
#   adding: output_masks/mask_7458.pt (deflated 100%)
#   adding: output_masks/mask_12107.pt (deflated 100%)
#   adding: output_masks/mask_4010.pt (deflated 100%)
#   adding: output_masks/mask_1271.pt (deflated 100%)
#   adding: output_masks/mask_560.pt (deflated 100%)
#   adding: output_masks/mask_10941.pt (deflated 100%)
#   adding: output_masks/mask_6885.pt (deflated 100%)
#   adding: output_masks/mask_12296.pt (deflated 100%)
#   adding: output_masks/mask_9615.pt (deflated 100%)
#   adding: output_masks/mask_687.pt (deflated 100%)
#   adding: output_masks/mask_7334.pt (deflated 100%)
#   adding: output_masks/mask_2572.pt (deflated 100%)
#   adding: output_masks/mask_6731.pt (deflated 100%)
#   adding: output_masks/mask_251.pt (deflated 100%)
#   adding: output_masks/mask_1315.pt (deflated 100%)
#   adding: output_masks/mask_2393.pt (deflated 100%)
#   adding: output_masks/mask_3572.pt (deflated 100%)
#   adding: output_masks/mask_8332.pt (deflated 100%)
#   adding: output_masks/mask_64.pt (deflated 100%)
#   adding: output_masks/mask_11046.pt (deflated 100%)
#   adding: output_masks/mask_8837.pt (deflated 100%)
#   adding: output_masks/mask_10476.pt (deflated 100%)
#   adding: output_masks/mask_3924.pt (deflated 100%)
#   adding: output_masks/mask_11327.pt (deflated 100%)
#   adding: output_masks/mask_11899.pt (deflated 100%)
#   adding: output_masks/mask_788.pt (deflated 100%)
#   adding: output_masks/mask_1029.pt (deflated 100%)
#   adding: output_masks/mask_3383.pt (deflated 100%)
#   adding: output_masks/mask_3009.pt (deflated 100%)
#   adding: output_masks/mask_8567.pt (deflated 100%)
#   adding: output_masks/mask_215.pt (deflated 100%)
#   adding: output_masks/mask_11461.pt (deflated 100%)
#   adding: output_masks/mask_12963.pt (deflated 100%)
#   adding: output_masks/mask_8981.pt (deflated 100%)
#   adding: output_masks/mask_5886.pt (deflated 100%)
#   adding: output_masks/mask_2221.pt (deflated 100%)
#   adding: output_masks/mask_5626.pt (deflated 100%)
#   adding: output_masks/mask_12536.pt (deflated 100%)
#   adding: output_masks/mask_4040.pt (deflated 100%)
#   adding: output_masks/mask_11192.pt (deflated 100%)
#   adding: output_masks/mask_7495.pt (deflated 100%)
#   adding: output_masks/mask_3874.pt (deflated 100%)
#   adding: output_masks/mask_4558.pt (deflated 100%)
#   adding: output_masks/mask_12487.pt (deflated 100%)
#   adding: output_masks/mask_989.pt (deflated 100%)
#   adding: output_masks/mask_1803.pt (deflated 100%)
#   adding: output_masks/mask_115.pt (deflated 100%)
#   adding: output_masks/mask_9876.pt (deflated 100%)
#   adding: output_masks/mask_11062.pt (deflated 100%)
#   adding: output_masks/mask_2454.pt (deflated 100%)
#   adding: output_masks/mask_2740.pt (deflated 100%)
#   adding: output_masks/mask_4496.pt (deflated 100%)
#   adding: output_masks/mask_319.pt (deflated 100%)
#   adding: output_masks/mask_8226.pt (deflated 100%)
#   adding: output_masks/mask_10802.pt (deflated 100%)
#   adding: output_masks/mask_8973.pt (deflated 100%)
#   adding: output_masks/mask_6083.pt (deflated 100%)
#   adding: output_masks/mask_12063.pt (deflated 100%)
#   adding: output_masks/mask_1887.pt (deflated 100%)
#   adding: output_masks/mask_5874.pt (deflated 100%)
#   adding: output_masks/mask_8271.pt (deflated 100%)
#   adding: output_masks/mask_6222.pt (deflated 100%)
#   adding: output_masks/mask_508.pt (deflated 100%)
#   adding: output_masks/mask_6872.pt (deflated 100%)
#   adding: output_masks/mask_5334.pt (deflated 100%)
#   adding: output_masks/mask_5759.pt (deflated 100%)
#   adding: output_masks/mask_9148.pt (deflated 100%)
#   adding: output_masks/mask_699.pt (deflated 100%)
#   adding: output_masks/mask_11720.pt (deflated 100%)
#   adding: output_masks/mask_12835.pt (deflated 100%)
#   adding: output_masks/mask_92.pt (deflated 100%)
#   adding: output_masks/mask_3334.pt (deflated 100%)
#   adding: output_masks/mask_7304.pt (deflated 100%)
#   adding: output_masks/mask_3904.pt (deflated 100%)
#   adding: output_masks/mask_3121.pt (deflated 100%)
#   adding: output_masks/mask_2678.pt (deflated 100%)
#   adding: output_masks/mask_6622.pt (deflated 100%)
#   adding: output_masks/mask_10618.pt (deflated 100%)
#   adding: output_masks/mask_9485.pt (deflated 100%)
#   adding: output_masks/mask_7368.pt (deflated 100%)
#   adding: output_masks/mask_9941.pt (deflated 100%)
#   adding: output_masks/mask_4334.pt (deflated 100%)
#   adding: output_masks/mask_11674.pt (deflated 100%)
#   adding: output_masks/mask_1760.pt (deflated 100%)
#   adding: output_masks/mask_8666.pt (deflated 100%)
#   adding: output_masks/mask_2101.pt (deflated 100%)
#   adding: output_masks/mask_8862.pt (deflated 100%)
#   adding: output_masks/mask_12925.pt (deflated 100%)
#   adding: output_masks/mask_840.pt (deflated 100%)
#   adding: output_masks/mask_1214.pt (deflated 100%)
#   adding: output_masks/mask_6665.pt (deflated 100%)
#   adding: output_masks/mask_10792.pt (deflated 100%)
#   adding: output_masks/mask_11173.pt (deflated 100%)
#   adding: output_masks/mask_7962.pt (deflated 100%)
#   adding: output_masks/mask_9756.pt (deflated 100%)
#   adding: output_masks/mask_3220.pt (deflated 100%)
#   adding: output_masks/mask_3848.pt (deflated 100%)
#   adding: output_masks/mask_9245.pt (deflated 100%)
#   adding: output_masks/mask_11563.pt (deflated 100%)
#   adding: output_masks/mask_1095.pt (deflated 100%)
#   adding: output_masks/mask_10456.pt (deflated 100%)
#   adding: output_masks/mask_6101.pt (deflated 100%)
#   adding: output_masks/mask_4346.pt (deflated 100%)
#   adding: output_masks/mask_8089.pt (deflated 100%)
#   adding: output_masks/mask_10137.pt (deflated 100%)
#   adding: output_masks/mask_4430.pt (deflated 100%)
#   adding: output_masks/mask_6552.pt (deflated 100%)
#   adding: output_masks/mask_12026.pt (deflated 100%)
#   adding: output_masks/mask_10548.pt (deflated 100%)
#   adding: output_masks/mask_4415.pt (deflated 100%)
#   adding: output_masks/mask_5241.pt (deflated 100%)
#   adding: output_masks/mask_11818.pt (deflated 100%)
#   adding: output_masks/mask_3479.pt (deflated 100%)
#   adding: output_masks/mask_1486.pt (deflated 100%)
#   adding: output_masks/mask_12031.pt (deflated 100%)
#   adding: output_masks/mask_12430.pt (deflated 100%)
#   adding: output_masks/mask_8581.pt (deflated 100%)
#   adding: output_masks/mask_5398.pt (deflated 100%)
#   adding: output_masks/mask_2852.pt (deflated 100%)
#   adding: output_masks/mask_11017.pt (deflated 100%)
#   adding: output_masks/mask_6158.pt (deflated 100%)
#   adding: output_masks/mask_7264.pt (deflated 100%)
#   adding: output_masks/mask_11868.pt (deflated 100%)
#   adding: output_masks/mask_4976.pt (deflated 100%)
#   adding: output_masks/mask_4313.pt (deflated 100%)
#   adding: output_masks/mask_2045.pt (deflated 100%)
#   adding: output_masks/mask_2031.pt (deflated 100%)
#   adding: output_masks/mask_8466.pt (deflated 100%)
#   adding: output_masks/mask_10335.pt (deflated 100%)
#   adding: output_masks/mask_8469.pt (deflated 100%)
#   adding: output_masks/mask_9742.pt (deflated 100%)
#   adding: output_masks/mask_5084.pt (deflated 100%)
#   adding: output_masks/mask_282.pt (deflated 100%)
#   adding: output_masks/mask_415.pt (deflated 100%)
#   adding: output_masks/mask_9305.pt (deflated 100%)
#   adding: output_masks/mask_9117.pt (deflated 100%)
#   adding: output_masks/mask_3907.pt (deflated 100%)
#   adding: output_masks/mask_2122.pt (deflated 100%)
#   adding: output_masks/mask_11446.pt (deflated 100%)
#   adding: output_masks/mask_333.pt (deflated 100%)
#   adding: output_masks/mask_6155.pt (deflated 100%)
#   adding: output_masks/mask_5614.pt (deflated 100%)
#   adding: output_masks/mask_12379.pt (deflated 100%)
#   adding: output_masks/mask_11792.pt (deflated 100%)
#   adding: output_masks/mask_628.pt (deflated 100%)
#   adding: output_masks/mask_10720.pt (deflated 100%)
#   adding: output_masks/mask_1796.pt (deflated 100%)
#   adding: output_masks/mask_265.pt (deflated 100%)
#   adding: output_masks/mask_5691.pt (deflated 100%)
#   adding: output_masks/mask_12528.pt (deflated 100%)
#   adding: output_masks/mask_1541.pt (deflated 100%)
#   adding: output_masks/mask_12798.pt (deflated 100%)
#   adding: output_masks/mask_3346.pt (deflated 100%)
#   adding: output_masks/mask_6453.pt (deflated 100%)
#   adding: output_masks/mask_5123.pt (deflated 100%)
#   adding: output_masks/mask_12465.pt (deflated 100%)
#   adding: output_masks/mask_9340.pt (deflated 100%)
#   adding: output_masks/mask_5996.pt (deflated 100%)
#   adding: output_masks/mask_5961.pt (deflated 100%)
#   adding: output_masks/mask_9839.pt (deflated 100%)
#   adding: output_masks/mask_7454.pt (deflated 100%)
#   adding: output_masks/mask_12067.pt (deflated 100%)
#   adding: output_masks/mask_280.pt (deflated 100%)
#   adding: output_masks/mask_2123.pt (deflated 100%)
#   adding: output_masks/mask_7469.pt (deflated 100%)
#   adding: output_masks/mask_8020.pt (deflated 100%)
#   adding: output_masks/mask_4362.pt (deflated 100%)
#   adding: output_masks/mask_8100.pt (deflated 100%)
#   adding: output_masks/mask_9184.pt (deflated 100%)
#   adding: output_masks/mask_8912.pt (deflated 100%)
#   adding: output_masks/mask_9378.pt (deflated 100%)
#   adding: output_masks/mask_9793.pt (deflated 100%)
#   adding: output_masks/mask_9343.pt (deflated 100%)
#   adding: output_masks/mask_11742.pt (deflated 100%)
#   adding: output_masks/mask_8533.pt (deflated 100%)
#   adding: output_masks/mask_12588.pt (deflated 100%)
#   adding: output_masks/mask_3132.pt (deflated 100%)
#   adding: output_masks/mask_5258.pt (deflated 100%)
#   adding: output_masks/mask_1815.pt (deflated 100%)
#   adding: output_masks/mask_1640.pt (deflated 100%)
# ...
#   adding: output_masks/mask_1304.pt (deflated 100%)
#   adding: output_masks/mask_10400.pt (deflated 100%)
#   adding: output_masks/mask_6333.pt (deflated 100%)
#   adding: output_masks/mask_4531.pt (deflated 100%)
#   adding: output_masks/mask_1821.pt (deflated 100%)
#   adding: output_masks/mask_3839.pt (deflated 100%)
#   adding: output_masks/mask_7448.pt (deflated 100%)
#   adding: output_masks/mask_12025.pt (deflated 100%)
#   adding: output_masks/mask_1618.pt (deflated 100%)
#   adding: output_masks/mask_8006.pt (deflated 100%)
#   adding: output_masks/mask_12562.pt (deflated 100%)
#   adding: output_masks/mask_9404.pt (deflated 100%)
#   adding: output_masks/mask_11443.pt (deflated 100%)
#   adding: output_masks/mask_4777.pt (deflated 100%)
#   adding: output_masks/mask_9155.pt (deflated 100%)
#   adding: output_masks/mask_3862.pt (deflated 100%)
#   adding: output_masks/mask_6183.pt (deflated 100%)
#   adding: output_masks/mask_2113.pt (deflated 100%)
#   adding: output_masks/mask_7954.pt (deflated 100%)
#   adding: output_masks/mask_3122.pt (deflated 100%)
#   adding: output_masks/mask_8241.pt (deflated 100%)
#   adding: output_masks/mask_9830.pt (deflated 100%)
#   adding: output_masks/mask_2283.pt (deflated 100%)
#   adding: output_masks/mask_2007.pt (deflated 100%)
#   adding: output_masks/mask_7144.pt (deflated 100%)
#   adding: output_masks/mask_3807.pt (deflated 100%)
#   adding: output_masks/mask_9718.pt (deflated 100%)
#   adding: output_masks/mask_4195.pt (deflated 100%)
#   adding: output_masks/mask_10988.pt (deflated 100%)
#   adding: output_masks/mask_11927.pt (deflated 100%)
#   adding: output_masks/mask_10681.pt (deflated 100%)
#   adding: output_masks/mask_12065.pt (deflated 100%)
#   adding: output_masks/mask_6522.pt (deflated 100%)
#   adding: output_masks/mask_4081.pt (deflated 100%)
#   adding: output_masks/mask_10554.pt (deflated 100%)
#   adding: output_masks/mask_2361.pt (deflated 100%)
#   adding: output_masks/mask_1003.pt (deflated 100%)
#   adding: output_masks/mask_10318.pt (deflated 100%)
#   adding: output_masks/mask_4943.pt (deflated 100%)
#   adding: output_masks/mask_9451.pt (deflated 100%)
#   adding: output_masks/mask_12251.pt (deflated 100%)
#   adding: output_masks/mask_6280.pt (deflated 100%)
#   adding: output_masks/mask_12328.pt (deflated 100%)
#   adding: output_masks/mask_12175.pt (deflated 100%)
#   adding: output_masks/mask_5753.pt (deflated 100%)
#   adding: output_masks/mask_12838.pt (deflated 100%)
#   adding: output_masks/mask_3490.pt (deflated 100%)
#   adding: output_masks/mask_12869.pt (deflated 100%)
#   adding: output_masks/mask_4451.pt (deflated 100%)
#   adding: output_masks/mask_1735.pt (deflated 100%)
#   adding: output_masks/mask_383.pt (deflated 100%)
#   adding: output_masks/mask_11546.pt (deflated 100%)
#   adding: output_masks/mask_4472.pt (deflated 100%)
#   adding: output_masks/mask_11745.pt (deflated 100%)
#   adding: output_masks/mask_6697.pt (deflated 100%)
#   adding: output_masks/mask_6923.pt (deflated 100%)
#   adding: output_masks/mask_3591.pt (deflated 100%)
#   adding: output_masks/mask_6648.pt (deflated 100%)
#   adding: output_masks/mask_7644.pt (deflated 100%)
#   adding: output_masks/mask_3401.pt (deflated 100%)
#   adding: output_masks/mask_12590.pt (deflated 100%)
#   adding: output_masks/mask_11985.pt (deflated 100%)
#   adding: output_masks/mask_3318.pt (deflated 100%)
#   adding: output_masks/mask_2241.pt (deflated 100%)
#   adding: output_masks/mask_8506.pt (deflated 100%)
#   adding: output_masks/mask_9415.pt (deflated 100%)
#   adding: output_masks/mask_9769.pt (deflated 100%)
#   adding: output_masks/mask_568.pt (deflated 100%)
#   adding: output_masks/mask_12930.pt (deflated 100%)
#   adding: output_masks/mask_12996.pt (deflated 100%)
#   adding: output_masks/mask_4127.pt (deflated 100%)
#   adding: output_masks/mask_2532.pt (deflated 100%)
#   adding: output_masks/mask_3605.pt (deflated 100%)
#   adding: output_masks/mask_9691.pt (deflated 100%)
#   adding: output_masks/mask_5606.pt (deflated 100%)
#   adding: output_masks/mask_10438.pt (deflated 100%)
#   adding: output_masks/mask_4470.pt (deflated 100%)
#   adding: output_masks/mask_1387.pt (deflated 100%)
#   adding: output_masks/mask_11575.pt (deflated 100%)
#   adding: output_masks/mask_293.pt (deflated 100%)
#   adding: output_masks/mask_2772.pt (deflated 100%)
#   adding: output_masks/mask_993.pt (deflated 100%)
#   adding: output_masks/mask_9074.pt (deflated 100%)
#   adding: output_masks/mask_2351.pt (deflated 100%)
#   adding: output_masks/mask_6679.pt (deflated 100%)
#   adding: output_masks/mask_3819.pt (deflated 100%)
#   adding: output_masks/mask_5977.pt (deflated 100%)
#   adding: output_masks/mask_9160.pt (deflated 100%)
#   adding: output_masks/mask_12391.pt (deflated 100%)
#   adding: output_masks/mask_10148.pt (deflated 100%)
#   adding: output_masks/mask_11880.pt (deflated 100%)
#   adding: output_masks/mask_4834.pt (deflated 100%)
#   adding: output_masks/mask_2004.pt (deflated 100%)
#   adding: output_masks/mask_4794.pt (deflated 100%)
#   adding: output_masks/mask_7345.pt (deflated 100%)
#   adding: output_masks/mask_11056.pt (deflated 100%)
#   adding: output_masks/mask_5592.pt (deflated 100%)
#   adding: output_masks/mask_1586.pt (deflated 100%)
#   adding: output_masks/mask_10581.pt (deflated 100%)
#   adding: output_masks/mask_10051.pt (deflated 100%)
#   adding: output_masks/mask_2962.pt (deflated 100%)
#   adding: output_masks/mask_10259.pt (deflated 100%)
#   adding: output_masks/mask_4801.pt (deflated 100%)
#   adding: output_masks/mask_4360.pt (deflated 100%)
#   adding: output_masks/mask_6712.pt (deflated 100%)
#   adding: output_masks/mask_5132.pt (deflated 100%)
#   adding: output_masks/mask_5809.pt (deflated 100%)
#   adding: output_masks/mask_6589.pt (deflated 100%)
#   adding: output_masks/mask_8576.pt (deflated 100%)
#   adding: output_masks/mask_4740.pt (deflated 100%)
#   adding: output_masks/mask_1672.pt (deflated 100%)
#   adding: output_masks/mask_2644.pt (deflated 100%)
#   adding: output_masks/mask_8258.pt (deflated 100%)
#   adding: output_masks/mask_1326.pt (deflated 100%)
#   adding: output_masks/mask_1542.pt (deflated 100%)
#   adding: output_masks/mask_11209.pt (deflated 100%)
#   adding: output_masks/mask_4555.pt (deflated 100%)
#   adding: output_masks/mask_7764.pt (deflated 100%)
#   adding: output_masks/mask_6230.pt (deflated 100%)
#   adding: output_masks/mask_7594.pt (deflated 100%)
#   adding: output_masks/mask_9852.pt (deflated 100%)
#   adding: output_masks/mask_6243.pt (deflated 100%)
#   adding: output_masks/mask_2670.pt (deflated 100%)
#   adding: output_masks/mask_7417.pt (deflated 100%)
#   adding: output_masks/mask_10750.pt (deflated 100%)
#   adding: output_masks/mask_10262.pt (deflated 100%)
#   adding: output_masks/mask_11460.pt (deflated 100%)
#   adding: output_masks/mask_4484.pt (deflated 100%)
#   adding: output_masks/mask_10639.pt (deflated 100%)
#   adding: output_masks/mask_2632.pt (deflated 100%)
#   adding: output_masks/mask_1379.pt (deflated 100%)
#   adding: output_masks/mask_1455.pt (deflated 100%)
#   adding: output_masks/mask_5944.pt (deflated 100%)
#   adding: output_masks/mask_6476.pt (deflated 100%)
#   adding: output_masks/mask_7391.pt (deflated 100%)
#   adding: output_masks/mask_11560.pt (deflated 100%)
#   adding: output_masks/mask_12881.pt (deflated 100%)
#   adding: output_masks/mask_2225.pt (deflated 100%)
#   adding: output_masks/mask_8302.pt (deflated 100%)
#   adding: output_masks/mask_6993.pt (deflated 100%)
#   adding: output_masks/mask_5569.pt (deflated 100%)
#   adding: output_masks/mask_6838.pt (deflated 100%)
#   adding: output_masks/mask_2346.pt (deflated 100%)
#   adding: output_masks/mask_1131.pt (deflated 100%)
#   adding: output_masks/mask_5520.pt (deflated 100%)
#   adding: output_masks/mask_4406.pt (deflated 100%)
#   adding: output_masks/mask_163.pt (deflated 100%)
#   adding: output_masks/mask_12385.pt (deflated 100%)
#   adding: output_masks/mask_5503.pt (deflated 100%)
#   adding: output_masks/mask_11470.pt (deflated 100%)
#   adding: output_masks/mask_3242.pt (deflated 100%)
#   adding: output_masks/mask_244.pt (deflated 100%)
#   adding: output_masks/mask_2149.pt (deflated 100%)
#   adding: output_masks/mask_3155.pt (deflated 100%)
#   adding: output_masks/mask_7440.pt (deflated 100%)
#   adding: output_masks/mask_2182.pt (deflated 100%)
#   adding: output_masks/mask_7754.pt (deflated 100%)
#   adding: output_masks/mask_11805.pt (deflated 100%)
#   adding: output_masks/mask_7798.pt (deflated 100%)
#   adding: output_masks/mask_8144.pt (deflated 100%)
#   adding: output_masks/mask_4055.pt (deflated 100%)
#   adding: output_masks/mask_9162.pt (deflated 100%)
#   adding: output_masks/mask_3914.pt (deflated 100%)
#   adding: output_masks/mask_10020.pt (deflated 100%)
#   adding: output_masks/mask_9301.pt (deflated 100%)
#   adding: output_masks/mask_10975.pt (deflated 100%)
#   adding: output_masks/mask_8074.pt (deflated 100%)
#   adding: output_masks/mask_2743.pt (deflated 100%)
#   adding: output_masks/mask_9472.pt (deflated 100%)
#   adding: output_masks/mask_5923.pt (deflated 100%)
#   adding: output_masks/mask_9606.pt (deflated 100%)
#   adding: output_masks/mask_8326.pt (deflated 100%)
#   adding: output_masks/mask_7113.pt (deflated 100%)
#   adding: output_masks/mask_1820.pt (deflated 100%)
#   adding: output_masks/mask_11244.pt (deflated 100%)
#   adding: output_masks/mask_12300.pt (deflated 100%)
#   adding: output_masks/mask_12807.pt (deflated 100%)
#   adding: output_masks/mask_3376.pt (deflated 100%)
#   adding: output_masks/mask_12153.pt (deflated 100%)
#   adding: output_masks/mask_4988.pt (deflated 100%)
#   adding: output_masks/mask_6115.pt (deflated 100%)
#   adding: output_masks/mask_3064.pt (deflated 100%)
#   adding: output_masks/mask_7252.pt (deflated 100%)
#   adding: output_masks/mask_734.pt (deflated 100%)
#   adding: output_masks/mask_828.pt (deflated 100%)
#   adding: output_masks/mask_9668.pt (deflated 100%)
#   adding: output_masks/mask_1773.pt (deflated 100%)
#   adding: output_masks/mask_3271.pt (deflated 100%)
#   adding: output_masks/mask_6632.pt (deflated 100%)
#   adding: output_masks/mask_8304.pt (deflated 100%)
#   adding: output_masks/mask_10104.pt (deflated 100%)
#   adding: output_masks/mask_10270.pt (deflated 100%)
#   adding: output_masks/mask_3629.pt (deflated 100%)
#   adding: output_masks/mask_8963.pt (deflated 100%)
#   adding: output_masks/mask_8560.pt (deflated 100%)
#   adding: output_masks/mask_8459.pt (deflated 100%)
#   adding: output_masks/mask_9023.pt (deflated 100%)
#   adding: output_masks/mask_9530.pt (deflated 100%)
#   adding: output_masks/mask_12460.pt (deflated 100%)
#   adding: output_masks/mask_7689.pt (deflated 100%)
#   adding: output_masks/mask_12298.pt (deflated 100%)
#   adding: output_masks/mask_8619.pt (deflated 100%)
#   adding: output_masks/mask_12555.pt (deflated 100%)
#   adding: output_masks/mask_2673.pt (deflated 100%)
#   adding: output_masks/mask_2831.pt (deflated 100%)
#   adding: output_masks/mask_12469.pt (deflated 100%)
#   adding: output_masks/mask_2198.pt (deflated 100%)
#   adding: output_masks/mask_11873.pt (deflated 100%)
#   adding: output_masks/mask_4325.pt (deflated 100%)
#   adding: output_masks/mask_8848.pt (deflated 100%)
#   adding: output_masks/mask_6318.pt (deflated 100%)
#   adding: output_masks/mask_673.pt (deflated 100%)
#   adding: output_masks/mask_4498.pt (deflated 100%)
#   adding: output_masks/mask_6562.pt (deflated 100%)
#   adding: output_masks/mask_3531.pt (deflated 100%)
#   adding: output_masks/mask_3041.pt (deflated 100%)
#   adding: output_masks/mask_9057.pt (deflated 100%)
#   adding: output_masks/mask_8409.pt (deflated 100%)
#   adding: output_masks/mask_1202.pt (deflated 100%)
#   adding: output_masks/mask_9468.pt (deflated 100%)
#   adding: output_masks/mask_6362.pt (deflated 100%)
#   adding: output_masks/mask_5434.pt (deflated 100%)
#   adding: output_masks/mask_6285.pt (deflated 100%)
#   adding: output_masks/mask_2407.pt (deflated 100%)
#   adding: output_masks/mask_6578.pt (deflated 100%)
#   adding: output_masks/mask_11373.pt (deflated 100%)
#   adding: output_masks/mask_1670.pt (deflated 100%)
#   adding: output_masks/mask_6759.pt (deflated 100%)
#   adding: output_masks/mask_11866.pt (deflated 100%)
#   adding: output_masks/mask_5071.pt (deflated 100%)
#   adding: output_masks/mask_8743.pt (deflated 100%)
#   adding: output_masks/mask_8150.pt (deflated 100%)
#   adding: output_masks/mask_2885.pt (deflated 100%)
#   adding: output_masks/mask_1322.pt (deflated 100%)
#   adding: output_masks/mask_2074.pt (deflated 100%)
#   adding: output_masks/mask_2997.pt (deflated 100%)
#   adding: output_masks/mask_11875.pt (deflated 100%)
#   adding: output_masks/mask_3205.pt (deflated 100%)
#   adding: output_masks/mask_8775.pt (deflated 100%)
#   adding: output_masks/mask_2940.pt (deflated 100%)
#   adding: output_masks/mask_777.pt (deflated 100%)
#   adding: output_masks/mask_12628.pt (deflated 100%)
#   adding: output_masks/mask_12081.pt (deflated 100%)
#   adding: output_masks/mask_2560.pt (deflated 100%)
#   adding: output_masks/mask_3342.pt (deflated 100%)
#   adding: output_masks/mask_8081.pt (deflated 100%)
#   adding: output_masks/mask_10689.pt (deflated 100%)
#   adding: output_masks/mask_6056.pt (deflated 100%)
#   adding: output_masks/mask_8512.pt (deflated 100%)
#   adding: output_masks/mask_12473.pt (deflated 100%)
#   adding: output_masks/mask_5442.pt (deflated 100%)
#   adding: output_masks/mask_25.pt (deflated 100%)
#   adding: output_masks/mask_3436.pt (deflated 100%)
#   adding: output_masks/mask_10062.pt (deflated 100%)
#   adding: output_masks/mask_7220.pt (deflated 100%)
#   adding: output_masks/mask_11883.pt (deflated 100%)
#   adding: output_masks/mask_1393.pt (deflated 100%)
#   adding: output_masks/mask_1454.pt (deflated 100%)
#   adding: output_masks/mask_2098.pt (deflated 100%)
#   adding: output_masks/mask_10004.pt (deflated 100%)
#   adding: output_masks/mask_7793.pt (deflated 100%)
#   adding: output_masks/mask_1378.pt (deflated 100%)
#   adding: output_masks/mask_2698.pt (deflated 100%)
#   adding: output_masks/mask_1317.pt (deflated 100%)
#   adding: output_masks/mask_11570.pt (deflated 100%)
#   adding: output_masks/mask_3710.pt (deflated 100%)
#   adding: output_masks/mask_6523.pt (deflated 100%)
#   adding: output_masks/mask_10413.pt (deflated 100%)
#   adding: output_masks/mask_3607.pt (deflated 100%)
#   adding: output_masks/mask_5732.pt (deflated 100%)
#   adding: output_masks/mask_7020.pt (deflated 100%)
#   adding: output_masks/mask_8988.pt (deflated 100%)
#   adding: output_masks/mask_3589.pt (deflated 100%)
#   adding: output_masks/mask_3528.pt (deflated 100%)
#   adding: output_masks/mask_3299.pt (deflated 100%)
#   adding: output_masks/mask_12215.pt (deflated 100%)
#   adding: output_masks/mask_2011.pt (deflated 100%)
#   adding: output_masks/mask_1681.pt (deflated 100%)
#   adding: output_masks/mask_8794.pt (deflated 100%)
#   adding: output_masks/mask_75.pt (deflated 100%)
#   adding: output_masks/mask_1368.pt (deflated 100%)
#   adding: output_masks/mask_1149.pt (deflated 100%)
#   adding: output_masks/mask_6420.pt (deflated 100%)
#   adding: output_masks/mask_74.pt (deflated 100%)
#   adding: output_masks/mask_9517.pt (deflated 100%)
#   adding: output_masks/mask_2029.pt (deflated 100%)
#   adding: output_masks/mask_8649.pt (deflated 100%)
#   adding: output_masks/mask_7222.pt (deflated 100%)
#   adding: output_masks/mask_3408.pt (deflated 100%)
#   adding: output_masks/mask_3855.pt (deflated 100%)
#   adding: output_masks/mask_11055.pt (deflated 100%)
#   adding: output_masks/mask_767.pt (deflated 100%)
#   adding: output_masks/mask_2966.pt (deflated 100%)
#   adding: output_masks/mask_3593.pt (deflated 100%)
#   adding: output_masks/mask_4021.pt (deflated 100%)
#   adding: output_masks/mask_6162.pt (deflated 100%)
#   adding: output_masks/mask_10138.pt (deflated 100%)
#   adding: output_masks/mask_9984.pt (deflated 100%)
#   adding: output_masks/mask_4994.pt (deflated 100%)
#   adding: output_masks/mask_8174.pt (deflated 100%)
#   adding: output_masks/mask_12295.pt (deflated 100%)
#   adding: output_masks/mask_4992.pt (deflated 100%)
#   adding: output_masks/mask_12448.pt (deflated 100%)
#   adding: output_masks/mask_3489.pt (deflated 100%)
#   adding: output_masks/mask_1806.pt (deflated 100%)
#   adding: output_masks/mask_2825.pt (deflated 100%)

# %%
import os

def load_all_masks(save_dir='output_masks'):
    files = sorted(os.listdir(save_dir))
    mask_files = [f for f in files if f.startswith('mask_') and f.endswith('.pt')]
    masks = []
    for file in mask_files:
        mask_path = os.path.join(save_dir, file)
        mask = torch.load(mask_path)
        masks.append(mask)
    return torch.cat(masks, dim=0)

masks_tensor = load_all_masks()
labels_tensor = torch.zeros(masks_tensor.size(0))  # Dummy labels; replace with actual labels if needed

dataset = TensorDataset(masks_tensor, labels_tensor)
dataloader = DataLoader(dataset, batch_size=10, shuffle=True)

# %%
x = torch.rand(2, 3, 4, 5)
x.shape
x.unsqueeze(0).shape
# Out:
# torch.Size([1, 2, 3, 4, 5])

# %%
from pathlib import Path
import random
from datetime import datetime
import time

from model import VPTREnc, VPTRDec, VPTRDisc, init_weights, VPTRFormerFAR, VPTRFormerNAR
from model import GDL, MSELoss, L1Loss, GANLoss
from utils import KTHDataset, BAIRDataset, MovingMNISTDataset
from utils import VidCenterCrop, VidPad, VidResize, VidNormalize, VidReNormalize, VidCrop, VidRandomHorizontalFlip, VidRandomVerticalFlip, VidToTensor
from utils import visualize_batch_clips, save_ckpt, load_ckpt, set_seed, AverageMeters, init_loss_dict, write_summary, resume_training, write_code_files
from utils import set_seed, PSNR, SSIM, MSEScore, get_dataloader

# !pip install lpips
import lpips
import numpy as np
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: lpips in /usr/local/lib/python3.10/dist-packages (0.1.4)
# Requirement already satisfied: torch>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from lpips) (2.0.0+cu118)
# Requirement already satisfied: scipy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from lpips) (1.10.1)
# Requirement already satisfied: tqdm>=4.28.1 in /usr/local/lib/python3.10/dist-packages (from lpips) (4.65.0)
# Requirement already satisfied: torchvision>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from lpips) (0.15.1+cu118)
# Requirement already satisfied: numpy>=1.14.3 in /usr/local/lib/python3.10/dist-packages (from lpips) (1.22.4)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips) (3.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips) (3.12.0)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips) (2.0.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips) (1.11.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips) (4.5.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=0.4.0->lpips) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=0.4.0->lpips) (16.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.2.1->lpips) (2.27.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.2.1->lpips) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=0.4.0->lpips) (2.1.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.2.1->lpips) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.2.1->lpips) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.2.1->lpips) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.2.1->lpips) (1.26.15)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=0.4.0->lpips) (1.3.0)

# %%
set_seed(2021)

# %%
resume_ckpt = Path('epoch_22.tar') #The trained Transformer checkpoint file
#resume_ckpt = None
resume_AE_ckpt = Path('epoch_4.tar') #The trained AutoEncoder checkpoint file
num_past_frames = 11
num_future_frames = 11
encH, encW, encC = 6, 6, 528
TSLMA_flag = False
rpe = True
model_flag = 'FAR' #'NAR' for NAR model, 'FAR' for FAR model

img_channels = 3 # 1 for KTH and MovingMNIST, 3 for BAIR
N = 1
loss_name_list = ['T_MSE', 'T_GDL', 'T_gan', 'T_total', 'Dtotal', 'Dfake', 'Dreal']

# %%
#Set the padding_type to be "zero" for BAIR dataset
VPTR_Enc = VPTREnc(img_channels, feat_dim = encC, n_downsampling = 3).to(device)
VPTR_Dec = VPTRDec(img_channels, feat_dim = encC, n_downsampling = 3, out_layer = 'Tanh').to(device)
VPTR_Enc = VPTR_Enc.eval()
VPTR_Dec = VPTR_Dec.eval()

if model_flag == 'NAR':
    VPTR_Transformer = VPTRFormerNAR(num_past_frames, num_future_frames, encH=encH, encW = encW, d_model=encC, 
                                         nhead=8, num_encoder_layers=4, num_decoder_layers=8, dropout=0.1, 
                                         window_size=4, Spatial_FFN_hidden_ratio=4, TSLMA_flag = TSLMA_flag, rpe=rpe).to(device)
else:
    VPTR_Transformer = VPTRFormerFAR(num_past_frames, num_future_frames, encH=encH, encW = encW, d_model=encC, 
                                    nhead=8, num_encoder_layers=6, dropout=0.1, 
                                    window_size=4, Spatial_FFN_hidden_ratio=4, rpe=rpe).to(device)

VPTR_Transformer = VPTR_Transformer.eval()

#load the trained autoencoder, we initialize the discriminator from scratch, for a balanced training
loss_dict, start_epoch = resume_training({'VPTR_Enc': VPTR_Enc, 'VPTR_Dec': VPTR_Dec}, {}, resume_AE_ckpt, loss_name_list, map_location=device)
if resume_ckpt is not None:
    loss_dict, start_epoch = resume_training({'VPTR_Transformer': VPTR_Transformer}, 
                                             {}, resume_ckpt, loss_name_list, map_location=device)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
train_loader, val_loader, test_loader, renorm_transform = get_dataloader('BAIR', N, 'Dataset_Student/train', 'Dataset_Student/val', test_past_frames = 11, 
                                                     test_future_frames = 11, ngpus = 1, num_workers = 1)

# %%
def plot_model_result(pred, fig_name, num_frames, n = 2):
    """
    Plot and save figure
    """
    fig, ax = plt.subplots(1, num_frames, figsize = (num_frames, 1))
    fig.subplots_adjust(wspace=0., hspace = 0.)

    for j in range(num_frames):
        ax[j].set_axis_off()
        
        img = pred[:, j, :, :, :].clone()
        img = renorm_transform(img)
        img = torch.clamp(img, min = 0., max = 1.)
        img = img[n, ...]

        img = transforms.ToPILImage()(img)
        ax[j].imshow(img, cmap = 'gray')
    # fig.savefig(f'{fig_name}.pdf', bbox_inches = 'tight')
    
def FAR_RIL_test_single_iter(sample, VPTR_Enc, VPTR_Dec, VPTR_Transformer, num_pred, device):
    """
    recurrently inference over Latent space, get a worse result
    """
    past_frames, future_frames = sample
    past_frames = past_frames.to(device)
    future_frames = future_frames.to(device)
    assert num_pred == future_frames.shape[1], "Mismatch between ground truth future frames length and num_pred"

    past_gt_feats = VPTR_Enc(past_frames)
    pred_feats = VPTR_Transformer(past_gt_feats)
    
    pred_frames = VPTR_Dec(pred_feats[:, -1:, ...])
    for i in range(1, num_pred):
        if i == 1:
            input_feats = torch.cat([past_gt_feats, pred_feats[:, -1:, ...]], dim = 1)
        elif i < VPTR_Transformer.num_future_frames:
            input_feats = torch.cat([input_feats, pred_future_feat], dim = 1)
        else:
            input_feats = torch.cat([input_feats, pred_future_feat], dim = 1)
            input_feats = input_feats[:, 1:, ...]
        
        pred_feats = VPTR_Transformer(input_feats)
        pred_future_frame = VPTR_Dec(pred_feats[:, -1:, ...])
        pred_future_feat = pred_feats[:, -1:, ...]
        pred_frames = torch.cat([pred_frames, pred_future_frame], dim = 1)
    
    return pred_frames, future_frames

def FAR_RIP_test_single_iter(sample, VPTR_Enc, VPTR_Dec, VPTR_Transformer, num_pred, device):
    """
    recurrently inference over pixel space
    """
    past_frames, future_frames = sample
    past_frames = past_frames.to(device)
    future_frames = future_frames.to(device)
    assert num_pred == future_frames.shape[1], "Mismatch between ground truth future frames length and num_pred"

    past_gt_feats = VPTR_Enc(past_frames)
    pred_feats = VPTR_Transformer(past_gt_feats)
    
    pred_frames = VPTR_Dec(pred_feats[:, -1:, ...])
    for i in range(1, num_pred):
        if i == 1:
            input_feats = torch.cat([past_gt_feats, pred_feats[:, -1:, ...]], dim = 1)
        elif i < VPTR_Transformer.num_future_frames:
            input_feats = torch.cat([input_feats, pred_future_feat], dim = 1)
        else:
            input_feats = torch.cat([input_feats, pred_future_feat], dim = 1)
            input_feats = input_feats[:, 1:, ...]
        
        pred_feats = VPTR_Transformer(input_feats)
        pred_future_frame = VPTR_Dec(pred_feats[:, -1:, ...])
        pred_future_feat = VPTR_Enc(pred_future_frame)
        pred_frames = torch.cat([pred_frames, pred_future_frame], dim = 1)
    
    return pred_frames, future_frames

def NAR_test_single_iter(sample, VPTR_Enc, VPTR_Dec, VPTR_Transformer, num_pred, device):
    """
    NAR model inference function, for the case num_pred is divisible for the num_future_frames of training. e.g. num_pred = 20, num_future_frames = 10
    """
    past_frames, future_frames = sample
    past_frames = past_frames.to(device)
    future_frames = future_frames.to(device)
    assert num_pred == future_frames.shape[1], "Mismatch between ground truth future frames length and num_pred"
    assert num_pred % VPTR_Transformer.num_future_frames == 0, "Mismatch of num_pred and trained Transformer"
    
    past_gt_feats = VPTR_Enc(past_frames)
    
    for i in range(0, num_pred//VPTR_Transformer.num_future_frames):
        pred_future_feats = VPTR_Transformer(past_gt_feats)
        if i == 0:
            pred_frames = VPTR_Dec(pred_future_feats)
        else:
            pred_frames = torch.cat([pred_frames, VPTR_Dec(pred_future_feats)], dim = 1)
        past_gt_feats = pred_future_feats
        
    
    return pred_frames, future_frames


def NAR_BAIR_2_to_28_test_single_iter(sample, VPTR_Enc, VPTR_Dec, VPTR_Transformer, num_pred, device):
    """
    Specifically for BAIR dataset, 2 -> 28 prediction.
    """
    past_frames, future_frames = sample
    past_frames = past_frames.to(device)
    future_frames = future_frames.to(device)
    assert num_pred == future_frames.shape[1], "Mismatch between ground truth future frames length and num_pred"
    #assert num_pred % VPTR_Transformer.num_future_frames == 0, "Mismatch of num_pred and trained Transformer"
    
    pred = []
    #prediction 1
    past_gt_feats = VPTR_Enc(past_frames)
    pred_future_feats = VPTR_Transformer(past_gt_feats)
    pred_frames = VPTR_Dec(pred_future_feats)
    pred.append(pred_frames)
    #prediction 2
    past_frames = pred_frames[:, -2:, ...]
    past_gt_feats = VPTR_Enc(past_frames)
    pred_future_feats = VPTR_Transformer(past_gt_feats)
    pred_frames = VPTR_Dec(pred_future_feats)
    pred.append(pred_frames)
    
    #prediction 3
    past_frames = pred_frames[:, -2:, ...]
    past_gt_feats = VPTR_Enc(past_frames)
    pred_future_feats = VPTR_Transformer(past_gt_feats)
    pred_frames = VPTR_Dec(pred_future_feats)
    pred.append(pred_frames[:, 0:-2, ...])
    pred_frames = torch.cat(pred, dim = 1)
    
    return pred_frames, future_frames

# %%
sample = next(iter(test_loader))
num_pred = 11
with torch.no_grad():
    pred_frames, gt_frames = FAR_RIL_test_single_iter(sample, VPTR_Enc, VPTR_Dec, VPTR_Transformer, num_pred, device)

# %%
Unet_masker_untrained = UNet(                 # model input channels (1 for gray-scale images, 3 for RGB, etc.)
    n_class=49,                      # model output channels (number of classes in your dataset)
)

# %%
from torch.nn.modules.loss import CrossEntropyLoss
from torch.optim.lr_scheduler import CosineAnnealingLR
from torch import optim


num_epochs = 5
#criterion = smp.losses.JaccardLoss(mode="multiclass")
weight = torch.ones(49)
weight[0] = 0.1
weight = weight.to(device)
steps = num_epochs * len(trainloader)
criterion = CrossEntropyLoss(weight=weight)
optimizer = optim.Adam(Unet_masker_untrained.parameters(), lr=0.0001)
scheduler = CosineAnnealingLR(optimizer, T_max=steps, eta_min=0.000001)

# %%
def compute_jaccard(ground_truth_mask, predicted_mask):
  jaccard = torchmetrics.JaccardIndex(task="multiclass", num_classes=49) #.to(device)
  return jaccard(torch.Tensor(ground_truth_mask), torch.Tensor(predicted_mask))

# %%
data, labels, masks =next(iter(trainloader))

# %%
data.shape
# Out:
# torch.Size([2, 22, 3, 160, 240])

# %%
renormed = renorm_transform(data[:, 0])

# %%
frame = rearrange(renormed, 'f c h w -> f h w c')

# %%
plt.imshow(frame[0])

# %%
unrenormed = data[0,0]
unrenormed = rearrange(unrenormed, 'c h w -> h w c')

# %%
plt.imshow(unrenormed)

# %%
from tqdm import tqdm
from einops import rearrange


def train_vptr_decoder_model(masker, encoder, decoder, transformer, trainloader, valloader, optimizer, criterion, device, epochs):
  # Training loop
  for epoch in range(epochs):
      # Training

      ## Set masker to train
      masker.train()
      encoder.eval()
      decoder.eval()
      transformer.eval()

      train_loss = 0
      train_tqdm = tqdm(trainloader, desc=f"Epoch {epoch+1}/{num_epochs} (Train)")

      for frames, labels, masks in train_tqdm:
          frames, labels, masks = frames.to(device), labels.to(device), masks.to(device)

          optimizer.zero_grad()

          encoded_frames = encoder(frames[:,:11])
          predicted_frames = transformer(encoded_frames)
          decoded_predicted_frames = decoder(predicted_frames)

          decoded_predicted_frames = rearrange(decoded_predicted_frames, 'b t c h w -> (b t) c h w')
          masks = rearrange(masks[:,11:,:,:], 'b t h w -> (b t) h w')
          predicted_masks = masker(decoded_predicted_frames)
          loss = criterion(predicted_masks, masks.long())

          loss.backward()
          optimizer.step()
          scheduler.step()

          train_loss += loss.item()
          train_tqdm.set_postfix({'train_loss': train_loss / (train_tqdm.n + 1), 'learning_rate': optimizer.param_groups[0]['lr']})

      # Validation

      ## Set masker to eval
      masker.eval()

      val_loss = 0
      val_tqdm = tqdm(valloader, desc=f"Epoch {epoch+1}/{num_epochs} (Val)")
      with torch.no_grad():
          last_frames_predicted_masks = []
          last_frames_actual_masks = []

          for frames, labels, masks in val_tqdm:
              frames, labels, masks = frames.to(device), labels.to(device), masks.to(device)

              encoded_frames = encoder(frames[:,:11])
              predicted_frames = transformer(encoded_frames)
              decoded_predicted_frames = decoder(predicted_frames)

              last_frames_actual_masks.append(masks[:,10].cpu())
              decoded_predicted_frames = rearrange(decoded_predicted_frames, 'b t c h w -> (b t) c h w')
              masks = rearrange(masks[:,11:,:,:], 'b t h w -> (b t) h w')
              predicted_masks = masker(decoded_predicted_frames)

              last_frames_predicted_masks.append(predicted_masks[[10,21]].cpu())

              loss = criterion(predicted_masks, masks.long())

              val_loss += loss.item()
              val_tqdm.set_postfix({'val_loss': val_loss / (val_tqdm.n + 1)})

          # Convert the tensors to numpy arrays for visualization
          outputs = torch.argmax(predicted_masks, dim=1)
          outputs = outputs.cpu().numpy()
          masks = masks.cpu().numpy()
          frames = frames.cpu().numpy()
          decoded_predicted_frames.cpu().numpy()
          # Choose the first sample in the batch to visualize
          sample_id = 10

          # Plot the predicted frame and real frame
          fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
          pred_frame = renorm_transform(decoded_predicted_frames)
          pred_frame = torch.clamp(pred_frame[sample_id], min=0., max=1.)
          ax1.imshow(rearrange(pred_frame, 'c h w -> h w c').cpu())
          ax1.set_title("Predicted Frame")
          
          ax2.imshow(rearrange(frames[0, sample_id+11], 'c h w -> h w c'))
          ax2.set_title("Real Frame")
          plt.show()

          # Plot the predicted mask and real mask
          fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
          ax1.imshow(outputs[sample_id])
          ax1.set_title("Predicted Mask")
          ax2.imshow(masks[sample_id])
          ax2.set_title("Real Mask")
          plt.show()

          results_mask_tensor = torch.cat(last_frames_predicted_masks, dim=0)  # Concatenate tensors
          actual_mask_tensor = torch.cat(last_frames_actual_masks, dim=0)
          print(results_mask_tensor.shape)
          print(actual_mask_tensor.shape)
          compute_jaccard(actual_mask_tensor, results_mask_tensor)


Unet_masker_untrained.to(device)
train_vptr_decoder_model(Unet_masker_untrained, VPTR_Enc, VPTR_Dec, VPTR_Transformer, trainloader, valloader, optimizer, criterion, device, num_epochs)
# Out:
# Epoch 1/5 (Train): 100%|██████████| 500/500 [04:36<00:00,  1.81it/s, train_loss=1.96, learning_rate=3.52e-5]
# Epoch 1/5 (Val): 100%|██████████| 500/500 [01:39<00:00,  5.04it/s, val_loss=1.93]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-fd56fbf1aff7> in <cell line: 103>()
#     101
#     102 Unet_masker_untrained.to(device)
# --> 103 train_vptr_decoder_model(Unet_masker_untrained, VPTR_Enc, VPTR_Dec, VPTR_Transformer, trainloader, valloader, optimizer, criterion, device, num_epochs)
#
# <ipython-input-58-fd56fbf1aff7> in train_vptr_decoder_model(masker, encoder, decoder, transformer, trainloader, valloader, optimizer, criterion, device, epochs)
#      97           results_mask_tensor = torch.cat(last_frames_predicted_masks, dim=0)  # Concatenate tensors
#      98           actual_mask_tensor = torch.cat(last_frames_actual_masks, dim=0)
# ---> 99           compute_jaccard(actual_mask_tensor, results_mask_tensor)
#     100
#     101
#
# <ipython-input-33-e3a0596f3b73> in compute_jaccard(ground_truth_mask, predicted_mask)
#       1 def compute_jaccard(ground_truth_mask, predicted_mask):
#       2   jaccard = torchmetrics.JaccardIndex(task="multiclass", num_classes=49) #.to(device)
# ----> 3   return jaccard(torch.Tensor(ground_truth_mask), torch.Tensor(predicted_mask))
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/torchmetrics/metric.py in forward(self, *args, **kwargs)
#     234             self._forward_cache = self._forward_full_state_update(*args, **kwargs)
#     235         else:
# --> 236             self._forward_cache = self._forward_reduce_state_update(*args, **kwargs)
#     237
#     238         return self._forward_cache
#
# /usr/local/lib/python3.10/dist-packages/torchmetrics/metric.py in _forward_reduce_state_update(self, *args, **kwargs)
#     300
#     301         # calculate batch state and compute batch value
# --> 302         self.update(*args, **kwargs)
#     303         batch_val = self.compute()
#     304
#
# /usr/local/lib/python3.10/dist-packages/torchmetrics/metric.py in wrapped_func(*args, **kwargs)
#     388             with torch.set_grad_enabled(self._enable_grad):
#     389                 try:
# --> 390                     update(*args, **kwargs)
#     391                 except RuntimeError as err:
#     392                     if "Expected all tensors to be on" in str(err):
#
# /usr/local/lib/python3.10/dist-packages/torchmetrics/classification/confusion_matrix.py in update(self, preds, target)
#     218         """Update state with predictions and targets."""
#     219         if self.validate_args:
# --> 220             _multiclass_confusion_matrix_tensor_validation(preds, target, self.num_classes, self.ignore_index)
#     221         preds, target = _multiclass_confusion_matrix_format(preds, target, self.ignore_index)
#     222         confmat = _multiclass_confusion_matrix_update(preds, target, self.num_classes)
#
# /usr/local/lib/python3.10/dist-packages/torchmetrics/functional/classification/confusion_matrix.py in _multiclass_confusion_matrix_tensor_validation(preds, target, num_classes, ignore_index)
#     270             )
#     271     else:
# --> 272         raise ValueError(
#     273             "Either `preds` and `target` both should have the (same) shape (N, ...), or `target` should be (N, ...)"
#     274             " and `preds` should be (N, C, ...)."
#
# ValueError: Either `preds` and `target` both should have the (same) shape (N, ...), or `target` should be (N, ...) and `preds` should be (N, C, ...).
